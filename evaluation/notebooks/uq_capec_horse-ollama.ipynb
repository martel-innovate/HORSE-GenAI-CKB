# %% [markdown]
# # Uncertainty Quantification for LLM-Generated Cybersecurity Mitigations
#
# **Method:** Predictive Entropy & Semantic Entropy, based on Kuhn, Gal & Farquhar, *"Semantic Uncertainty: Linguistic Invariances for Uncertainty Estimation in Natural Language Generation"*, ICLR 2023, and the updated Nature 2024 paper *"Detecting Hallucinations in Large Language Models Using Semantic Entropy."*
#
# **Adaptation for structured outputs:** the original method targets short-form QA. We adapt it for long-form structured JSON (cybersecurity mitigation lists) by: (1) converting JSON to natural language before NLI clustering, (2) using a Monte Carlo entropy estimator that stays in log-space to avoid numerical collapse for long sequences, (3) applying length normalization to make entropy comparable across attacks with different output lengths.
#
# **LLM:** DeepSeek R1 8B — from the [HORSE-GenAI-CKB](https://github.com/martel-innovate/HORSE-GenAI-CKB) model list.
#
# **Data:** Real CAPEC attack–mitigation pairs, fetched live from the HORSE repo.
#
# **Backends:** CUDA GPU → HuggingFace 4-bit (auto-detected) | Apple Silicon → Ollama (auto-detected)

# %% [markdown]
# ---
# ## Background
#
# ### The problem
#
# When an LLM generates cybersecurity mitigations, we have no guarantee the output is reliable. The model might hallucinate non-existent techniques, suggest irrelevant countermeasures, or contradict itself across runs. We need a principled way to **quantify how uncertain** the model is about its output.
#
# ### Predictive entropy (PE)
#
# Sample $M$ responses $s_1, \dots, s_M$ from the model for the same prompt. Each response has a sequence log-probability $\log p(s_i|x) = \sum_t \log p(\text{token}_t | \text{context})$. Predictive entropy is the Monte Carlo estimate of the true conditional entropy:
#
# $$PE = -\frac{1}{M}\sum_{i=1}^{M} \log p(s_i | x)$$
#
# This is the average negative log-likelihood — how "surprised" the model is by its own outputs. No normalization or exponentiation needed. Corresponds to `regular_entropy` in the Kuhn et al. codebase.
#
# **Limitation:** PE treats every lexically distinct response as separate. "Use a WAF" and "Deploy a web application firewall" are counted as different outcomes, inflating the entropy with phrasing variation.
#
# ### Semantic entropy (SE) — Kuhn et al. 2023
#
# Semantic entropy fixes this by **clustering responses by meaning** before computing entropy:
#
# 1. **Cluster** responses into semantic equivalence classes $C_1, \dots, C_K$ using bidirectional NLI entailment (DeBERTa-Large-MNLI). Two responses are equivalent iff A entails B **and** B entails A.
# 2. **Aggregate** log-probabilities within each cluster: $\log p(C_k) = \text{logsumexp}(\log p(s_i) : s_i \in C_k)$.
# 3. **Compute** entropy weighted by cluster frequencies: $SE = -\sum_k \frac{|C_k|}{M} \cdot \log p(C_k)$.
#
# This is a Monte Carlo estimate of $H[C|x]$ — the entropy of the model's distribution over **meanings**, not strings. It stays entirely in log-space (no exponentiation of sequence probabilities), making it numerically stable even for long outputs.
#
# **Key property:** $SE \leq PE$ always. The gap $PE - SE$ is the phrasing uncertainty (irrelevant) that clustering removes. When $SE \approx PE$, the model genuinely disagrees about the answer. When $SE \ll PE$, it says the same thing in different words.
#
# ### Discrete semantic entropy (DSE)
#
# A simpler variant that uses only cluster counts, no log-probs: $DSE = -\sum_k \frac{|C_k|}{M} \log \frac{|C_k|}{M}$. Range $[0, \log M]$. Naturally length-independent. Called `cluster_assignment_entropy` in the paper. Works as a black-box metric when log-probs are unavailable.
#
# ### Length normalization
#
# Sequence log-probabilities scale with output length (more tokens → more negative → higher entropy). To compare PE and SE across attacks with different output lengths, we divide by the average token count: $PE_{\text{norm}} = PE / \bar{T}$, $SE_{\text{norm}} = SE / \bar{T}$. This gives **per-token entropy** — comparable across attacks. DSE requires no normalization (it doesn't use log-probs).
#
# ### Three metrics computed in this notebook
#
# | Metric | Formula | Comparable | What it measures |
# |--------|---------|------------|-----------------|
# | $PE_{\text{norm}}$ | $-\frac{1}{M\bar{T}}\sum_i \log p(s_i|x)$ | Yes | Per-token surprise (total uncertainty) |
# | $SE_{\text{norm}}$ | $-\frac{1}{\bar{T}}\sum_k \frac{|C_k|}{M} \cdot \text{logsumexp}(C_k)$ | Yes | Per-token semantic uncertainty |
# | $DSE$ | $-\sum_k \frac{|C_k|}{M} \log \frac{|C_k|}{M}$ | Yes | Cluster disagreement (no log-probs) |
#
# All three are comparable across attacks. $SE_{\text{norm}} \leq PE_{\text{norm}}$ always. Higher values = more uncertain = less reliable.

# %% [markdown]
# ---
# ## 0. Install dependencies

# %%
import platform, subprocess, sys

# Core deps (always needed)
subprocess.check_call([sys.executable, '-m', 'pip', 'install', '-q',
    'transformers', 'accelerate', 'sentence-transformers',
    'pandas', 'matplotlib', 'seaborn', 'requests', 'scikit-learn', 'scipy'])

# bitsandbytes only works on CUDA — skip on Mac to avoid install errors
import torch
if torch.cuda.is_available():
    subprocess.check_call([sys.executable, '-m', 'pip', 'install', '-q', 'bitsandbytes'])
    print('bitsandbytes installed (CUDA detected)')
else:
    print('Skipping bitsandbytes (no CUDA) — will use Ollama backend')
# Out:
# Skipping bitsandbytes (no CUDA) — will use Ollama backend

# %% [markdown]
# ## 1. Imports & configuration

# %%
import numpy as np
import pandas as pd
import torch
import platform
import subprocess
import requests
import json
import warnings
from scipy.special import logsumexp
from sklearn.metrics.pairwise import cosine_similarity
from sentence_transformers import SentenceTransformer
from transformers import pipeline as hf_pipeline
import matplotlib.pyplot as plt
import seaborn as sns

warnings.filterwarnings("ignore", message=".*pad_token_id.*")
warnings.filterwarnings("ignore", message=".*pipelines sequentially.*")

# ══════════════════════════════════════════════════════════
# MODEL SELECTION — change OLLAMA_MODEL to switch models
# ══════════════════════════════════════════════════════════
# Available models from the HORSE repo (all work with Ollama):
#   "deepseek-r1:8b"                         — DeepSeek R1 8B
#   "llama3.1:8b"                             — Meta Llama 3.1 8B
#   "granite3-dense:8b"                       — IBM Granite 3 Dense 8B
#   "llama2:7b"                               — Meta Llama 2 7B
#   "llama2:13b"                              — Meta Llama 2 13B (needs ~10GB)
#   "ALIENTELLIGENCE/cyberaisecurity:latest"  — ALIEN cyberAI security
#
# To switch: 1) change OLLAMA_MODEL below
#            2) run: ollama pull <model_name>
#            3) restart the notebook

OLLAMA_MODEL = "llama3.1:8b"  # ← CHANGE THIS TO SWITCH MODELS

# HuggingFace equivalent (only used on CUDA, not on Mac)
LLM_NAME = "deepseek-ai/DeepSeek-R1-Distill-Llama-8B"

# ── Sampling parameters ────────────────────────────────────
M = 8                  # responses per query (Kuhn et al. use 5-10)
TEMPERATURE = 0.8      # 0.7 as recommended by Kuhn et al.
MAX_NEW_TOKENS = 512   # real CAPEC mitigations can be long
COSINE_THRESHOLD = 0.8
MAX_ATTACKS = 110     # set to None for full run, or e.g. 20 for testing

# %% [markdown]
# ## 2. Auto-detect backend
#
# Detects the runtime environment and picks the best available backend:
# - **CUDA GPU** → HuggingFace with 4-bit quantization (Colab / Linux with NVIDIA GPU)
# - **Apple Silicon** → Ollama local server (M1/M2/M3/M4 Mac, needs `ollama serve` running)
# - **CPU-only** → Ollama fallback

# %%
# ── Detect hardware ─────────────────────────────────────────
HAS_CUDA = torch.cuda.is_available()
IS_MAC_ARM = platform.system() == "Darwin" and platform.machine() == "arm64"
HAS_MPS = hasattr(torch.backends, "mps") and torch.backends.mps.is_available()

def ollama_available():
    """Check if Ollama is running and has the required model."""
    try:
        r = requests.get("http://localhost:11434/api/tags", timeout=3)
        models = [m["name"] for m in r.json().get("models", [])]
        if OLLAMA_MODEL in models or OLLAMA_MODEL.split(":")[0] in [m.split(":")[0] for m in models]:
            return True
        print(f"Ollama running but model '{OLLAMA_MODEL}' not found.")
        print(f"Available: {models}")
        print(f"Run: ollama pull {OLLAMA_MODEL}")
        return False
    except Exception:
        return False

if HAS_CUDA:
    BACKEND = "huggingface"
    DEVICE = "cuda"
    print(f"CUDA detected ({torch.cuda.get_device_name(0)}) → HuggingFace backend")
elif ollama_available():
    BACKEND = "ollama"
    DEVICE = "mps" if HAS_MPS else "cpu"
    print(f"Ollama detected → Ollama backend (torch device: {DEVICE})")
else:
    BACKEND = None
    DEVICE = "cpu"
    print("ERROR: No CUDA GPU and no Ollama server detected.")
    print("  Option A (Mac): install Ollama → brew install ollama && ollama serve")
    print(f"                   then: ollama pull {OLLAMA_MODEL}")
    print("  Option B (Colab): Runtime → Change runtime type → T4 GPU")
    raise RuntimeError("No usable LLM backend found.")

print(f"\nBackend: {BACKEND}  |  Device: {DEVICE}")
# Out:
# Ollama detected → Ollama backend (torch device: mps)
#
# Backend: ollama  |  Device: mps

# %% [markdown]
# ## 3. Load models
#
# Three models loaded simultaneously:
#
# - **DeepSeek R1 8B** — the LLM. Generates mitigation JSON responses. On CUDA: HuggingFace 4-bit quantization (~5 GB VRAM). On Mac: via Ollama server.
# - **all-MiniLM-L6-v2** (~80 MB) — Sentence-BERT. Encodes responses into 384-dim vectors for cosine-based clustering.
# - **DeBERTa-Large-MNLI** (~1.5 GB) — NLI classifier. Determines bidirectional entailment for Kuhn et al.'s semantic clustering. This is the same model family used in the original paper.

# %%
# ── LLM ─────────────────────────────────────────────────────
if BACKEND == "huggingface":
    from transformers import AutoTokenizer, AutoModelForCausalLM, BitsAndBytesConfig
    bnb_config = BitsAndBytesConfig(load_in_4bit=True, bnb_4bit_compute_dtype=torch.float16)
    tokenizer = AutoTokenizer.from_pretrained(LLM_NAME)
    tokenizer.pad_token = tokenizer.eos_token
    llm = AutoModelForCausalLM.from_pretrained(
        LLM_NAME, quantization_config=bnb_config, device_map="auto"
    )
    llm.eval()
    print(f"LLM loaded: {LLM_NAME} (HuggingFace 4-bit)")
else:
    print(f"LLM: Ollama → {OLLAMA_MODEL} (running on localhost:11434)")

# ── Sentence-BERT ───────────────────────────────────────────
embedder = SentenceTransformer("all-MiniLM-L6-v2", device=DEVICE)
print("Sentence-BERT loaded.")

# ── DeBERTa NLI ─────────────────────────────────────────────
nli_device = 0 if HAS_CUDA else (-1 if DEVICE == "cpu" else "mps")
# MPS can be flaky with some HF pipelines — fall back to CPU if needed
try:
    nli = hf_pipeline("text-classification", model="microsoft/deberta-large-mnli", device=nli_device)
except Exception:
    nli = hf_pipeline("text-classification", model="microsoft/deberta-large-mnli", device=-1)
    print("(DeBERTa fell back to CPU)")
print("DeBERTa-Large-MNLI loaded.")
print("\nAll models ready.")
# Out:
# LLM: Ollama → llama3.1:8b (running on localhost:11434)
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Sentence-BERT loaded.
# Loading weights:   0%|          | 0/392 [00:00<?, ?it/s]
# DebertaForSequenceClassification LOAD REPORT from: microsoft/deberta-large-mnli
# Key    | Status     |  |
# -------+------------+--+-
# config | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Exception in thread Thread-auto_conversion:
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/jacopotalpini/Desktop/MARTEL/martel_env/lib/python3.10/site-packages/transformers/safetensors_conversion.py", line 117, in auto_conversion
#     raise e
#   File "/Users/jacopotalpini/Desktop/MARTEL/martel_env/lib/python3.10/site-packages/transformers/safetensors_conversion.py", line 96, in auto_conversion
#     sha = get_conversion_pr_reference(api, pretrained_model_name_or_path, **cached_file_kwargs)
#   File "/Users/jacopotalpini/Desktop/MARTEL/martel_env/lib/python3.10/site-packages/transformers/safetensors_conversion.py", line 72, in get_conversion_pr_reference
#     spawn_conversion(token, private, model_id)
#   File "/Users/jacopotalpini/Desktop/MARTEL/martel_env/lib/python3.10/site-packages/transformers/safetensors_conversion.py", line 48, in spawn_conversion
#     result = httpx.post(sse_url, follow_redirects=True, json=data).json()
#   File "/Users/jacopotalpini/Desktop/MARTEL/martel_env/lib/python3.10/site-packages/httpx/_models.py", line 832, in json
#     return jsonlib.loads(self.content, **kwargs)
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/json/__init__.py", line 346, in loads
#     return _default_decoder.decode(s)
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/json/decoder.py", line 337, in decode
#     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/json/decoder.py", line 355, in raw_decode
#     raise JSONDecodeError("Expecting value", s, err.value) from None
# json.decoder.JSONDecodeError: Expecting value: line 1 column 1 (char 0)
# DeBERTa-Large-MNLI loaded.
#
# All models ready.

# %% [markdown]
# ## 4. Load CAPEC data from the HORSE repo

# %%
CAPEC_URL = (
    "https://raw.githubusercontent.com/martel-innovate/HORSE-GenAI-CKB/"
    "main/output/scraper/capec.csv"
)

capec_df = pd.read_csv(CAPEC_URL)
print(f"CSV shape: {capec_df.shape}  |  Columns: {list(capec_df.columns)}")

# ── Auto-detect columns ────────────────────────────────────
cols_lower = {c.lower().strip(): c for c in capec_df.columns}

attack_col = None
for candidate in ["attack", "attacks", "attack_name", "name", "attack pattern", "attack_pattern"]:
    if candidate in cols_lower:
        attack_col = cols_lower[candidate]
        break

mitigation_col = None
for candidate in ["mitigations", "mitigation", "mitigation_list", "solutions"]:
    if candidate in cols_lower:
        mitigation_col = cols_lower[candidate]
        break

assert attack_col and mitigation_col, (
    f"Could not detect columns. Found: {list(capec_df.columns)}. "
    f"Set attack_col and mitigation_col manually."
)
print(f"Attack column → '{attack_col}'  |  Mitigation column → '{mitigation_col}'")

# ── Build attack list ───────────────────────────────────────
attacks = []
for _, row in capec_df.iterrows():
    a = str(row[attack_col]).strip()
    m = str(row[mitigation_col]).strip()
    if a and a != "nan" and m and m != "nan":
        attacks.append({"attack": a, "mitigations": m})

print(f"{len(attacks)} attacks loaded.")
if MAX_ATTACKS is not None:
    attacks = attacks[:MAX_ATTACKS]
    print(f"Using first {MAX_ATTACKS} (set MAX_ATTACKS = None for full run).")
# Out:
# CSV shape: (350, 2)  |  Columns: ['attacks', 'mitigations']
# Attack column → 'attacks'  |  Mitigation column → 'mitigations'
# 350 attacks loaded.
# Using first 110 (set MAX_ATTACKS = None for full run).

# %% [markdown]
# ## 5. Prompt template
#
# Identical to `mitigation_generator.py` line 25.

# %%
def build_prompt(attack, mitigations):
    return (
        f"return a list of mitigation names and their priority, in json format, "
        f"for the attack '{attack}', including and expanding this mitigation list "
        f"according to CAPEC {mitigations}. Please generate data in the following "
        f"JSON format: The root object contains a key named 'mitigations', 'mitigations' "
        f"should be an array of objects and each object in the 'mitigations' array should "
        f"have two fields: 'name' (A string that provides the name of the mitigation), "
        f"'priority' (An integer that indicates the priority of the mitigation, with 1 being "
        f"the highest priority). Priorities are ordered unique numbers, where 1 means that "
        f"the mitigation is urgent and will be applied first, then all the others will be "
        f"applied in order and there can't be two mitigations with the same priority. "
        f"In the response I just want the json with no other text"
    )

# %% [markdown]
# ## 6. Generate M responses with log-probabilities
#
# For each prompt, we sample $M$ independent responses using `temperature = 0.7` (as recommended by Kuhn et al.). Each sample returns:
#
# - **text** — the raw generated string (JSON with mitigations)
# - **log\_prob** — sequence log-probability: $\log p(s|x) = \sum_{t=1}^{T} \log p(\text{token}_t | \text{context})$
# - **n\_tokens** — number of generated tokens $T$ (needed for length normalization)
#
# Two backends with identical interface:
# - **HuggingFace:** `model.generate(output_scores=True)` → per-token logits → sum of log-softmax at each position.
# - **Ollama:** `/api/generate` with `logprobs: true` → list of `{token, logprob}` objects → sum.

# %%
def _sample_huggingface(prompt, m, temperature):
    """Sample via HuggingFace generate() with output_scores."""
    messages = [{"role": "user", "content": prompt}]
    chat_input = tokenizer.apply_chat_template(
        messages, tokenize=False, add_generation_prompt=True
    )
    inputs = tokenizer(chat_input, return_tensors="pt").to(llm.device)
    prompt_len = inputs["input_ids"].shape[1]

    results = []
    for i in range(m):
        with torch.no_grad():
            output = llm.generate(
                **inputs,
                max_new_tokens=MAX_NEW_TOKENS,
                temperature=temperature,
                do_sample=True,
                return_dict_in_generate=True,
                output_scores=True,
            )
        gen_ids = output.sequences[0, prompt_len:]
        text = tokenizer.decode(gen_ids, skip_special_tokens=True)

        log_prob = 0.0
        for t, scores in enumerate(output.scores):
            if t >= len(gen_ids):
                break
            log_probs_t = torch.log_softmax(scores[0], dim=-1)
            log_prob += log_probs_t[gen_ids[t]].item()

        n_tokens = len(gen_ids)
        results.append({"text": text, "log_prob": log_prob, "n_tokens": n_tokens})
        print(f"    sample {i+1}/{m}  (log_prob={log_prob:.1f}, tokens={n_tokens})")
    return results


def _sample_ollama(prompt, m, temperature):
    """Sample via Ollama /api/generate with logprobs."""
    results = []
    for i in range(m):
        resp = requests.post("http://localhost:11434/api/generate", json={
            "model": OLLAMA_MODEL,
            "prompt": prompt,
            "stream": False,
            "think": False,  # disable <think> reasoning — we need the JSON directly
            "options": {
                "temperature": temperature,
                "num_predict": MAX_NEW_TOKENS,
            },
            # Request log-probs (Ollama >= 0.12.11)
            "logprobs": True,
        }, timeout=300)
        data = resp.json()
        text = data.get("response", "")

        # DeepSeek R1 may still put content in 'thinking' field
        if not text.strip():
            text = data.get("thinking", "")
            if text and i == 0:
                print("    (using 'thinking' field — model used chain-of-thought)")

        # Extract log-prob: Ollama (>= 0.12.11) returns logprobs as
        # a list of {"token": str, "logprob": float, ...} objects.
        logprobs_list = data.get("logprobs", None)
        if isinstance(logprobs_list, list) and len(logprobs_list) > 0:
            log_prob = sum(entry["logprob"] for entry in logprobs_list
                          if isinstance(entry, dict) and "logprob" in entry)
        else:
            # Ollama too old or logprobs not supported for this model
            log_prob = 0.0
            if i == 0:
                print("    ⚠ Ollama did not return logprobs — only count-based SE will be valid.")
                print("      Upgrade Ollama to >= 0.12.11 or use HuggingFace backend for weighted SE.")

        n_tokens = len(logprobs_list) if isinstance(logprobs_list, list) and logprobs_list else data.get("eval_count", max(1, len(text.split())))
        results.append({"text": text, "log_prob": log_prob, "n_tokens": n_tokens})
        print(f"    sample {i+1}/{m}  (log_prob={log_prob:.1f}, tokens={n_tokens})")
    return results


def sample_with_logprobs(prompt, m=M, temperature=TEMPERATURE):
    if BACKEND == "huggingface":
        return _sample_huggingface(prompt, m, temperature)
    else:
        return _sample_ollama(prompt, m, temperature)

# %% [markdown]
# ## 7. Clustering functions
#
# Two clustering methods, applied to the **natural language converted** responses (not raw JSON):
#
# ### Cosine-based clustering
# Embed responses with Sentence-BERT, compute pairwise cosine similarity. Greedy assignment: group responses with similarity $\geq \tau$ (default 0.8). Simple but introduces a threshold hyperparameter.
#
# ### NLI-based clustering (Kuhn et al. 2023)
# Two responses are semantically equivalent iff DeBERTa judges A→B as entailment **and** B→A as entailment (bidirectional). No threshold needed — the NLI model gives a categorical label. Greedy assignment: each new response is compared to existing cluster representatives.
#
# **Known limitation for structured outputs:** DeBERTa was trained on sentence pairs, not ordered lists of mitigations. It tends to over-merge responses that have overlapping vocabulary but different content or ordering. This biases DSE and SE toward 0 (under-counting real differences). The JSON→NL conversion (Section 8b) partially mitigates this by making ordering explicit in the text.

# %%
def cluster_by_cosine(responses, threshold=COSINE_THRESHOLD):
    """Greedy clustering by cosine similarity of sentence embeddings."""
    emb = embedder.encode(responses)
    sim = cosine_similarity(emb)
    assigned = [False] * len(responses)
    clusters = []
    for i in range(len(responses)):
        if assigned[i]:
            continue
        cluster = [i]
        assigned[i] = True
        for j in range(i + 1, len(responses)):
            if not assigned[j] and sim[i][j] >= threshold:
                cluster.append(j)
                assigned[j] = True
        clusters.append(cluster)
    return clusters


def are_equivalent_nli(a, b):
    """Bidirectional entailment check."""
    fwd = nli(f"{a}</s></s>{b}", truncation=True)[0]["label"]
    bwd = nli(f"{b}</s></s>{a}", truncation=True)[0]["label"]
    return fwd == "ENTAILMENT" and bwd == "ENTAILMENT"


def cluster_by_nli(responses):
    """Greedy NLI clustering (Kuhn et al. 2023)."""
    clusters = []
    for i, r in enumerate(responses):
        added = False
        for cluster in clusters:
            if are_equivalent_nli(r, responses[cluster[0]]):
                cluster.append(i)
                added = True
                break
        if not added:
            clusters.append([i])
    return clusters

# %% [markdown]
# ## 8. Entropy functions
#
# Three metrics, each working in log-space (no exponentiation → works for long outputs).
#
# | # | Metric | Formula | Uses log-probs | Uses clusters | Comparable across attacks |
# |---|--------|---------|---------------|--------------|-------------------------|
# | 1 | **Predictive entropy** | $PE = -\frac{1}{M}\sum_i \log p(s_i|x)$ | Yes | No | After length normalization |
# | 2 | **Discrete SE** | $H = -\sum_k \frac{|C_k|}{M} \log \frac{|C_k|}{M}$ | No | Yes | Yes (always) |
# | 3 | **Semantic entropy (MC)** | $SE = -\sum_k \frac{|C_k|}{M} \cdot \text{logsumexp}(\log p_{C_k})$ | Yes | Yes | After length normalization |
#
# Metric 3 is the key contribution: it merges model confidence (log-probs) with semantic clustering into one number, using an MC estimator that stays in log-space. It satisfies $SE \leq PE$ by construction.

# %%
# ════════════════════════════════════════════════════════════
# METRIC 1: Predictive entropy (MC estimate)
# Paper: 'regular_entropy' in Kuhn et al. code
# ════════════════════════════════════════════════════════════

def predictive_entropy(log_probs):
    """MC estimate of conditional entropy.
    PE = -1/M * sum_i log p(s_i | x)
    Average negative log-likelihood. No exponentiation.
    """
    return -np.sum(np.array(log_probs)) / len(log_probs)


# ════════════════════════════════════════════════════════════
# METRIC 2: Discrete semantic entropy (cluster counts only)
# Paper: 'cluster_assignment_entropy' in Kuhn et al. code
# ════════════════════════════════════════════════════════════

def discrete_semantic_entropy(clusters, m):
    """Shannon entropy over cluster frequency distribution.
    H = -sum_k (|C_k|/M) * log(|C_k|/M)
    No log-probs needed. Range [0, log(M)].
    Naturally length-independent.
    """
    counts = np.array([len(c) for c in clusters])
    probs = counts / m
    probs = probs[probs > 0]
    return max(0.0, -np.sum(probs * np.log(probs)))


# ════════════════════════════════════════════════════════════
# METRIC 3: Semantic entropy (MC estimate, log-prob weighted)
# Merges model confidence + cluster structure in one number.
# MC estimator of H[C|x] — stays in log-space, no exp().
# ════════════════════════════════════════════════════════════

def semantic_entropy(clusters, log_probs):
    """MC estimate of semantic entropy.
    SE = -sum_k (|C_k|/M) * logsumexp(log_probs in cluster k)

    Each cluster's log-probability is aggregated via logsumexp,
    then weighted by cluster frequency |C_k|/M.

    Properties:
      - SE <= PE (provably, by Jensen's inequality on logsumexp)
      - No exponentiation of raw log-probs (works for any length)
      - Merges model confidence with semantic clustering
    """
    lp = np.array(log_probs)
    m = len(log_probs)
    se = 0.0
    for c in clusters:
        weight = len(c) / m
        log_p_ck = logsumexp(lp[c])  # stays in log-space
        se += weight * log_p_ck
    return -se  # negate: log_p_ck is negative, so -se is positive


# ════════════════════════════════════════════════════════════
# Length normalization for cross-attack comparison
# Divide PE and SE by average token count to get per-token values.
# Applied AFTER computation on raw log-probs (not before logsumexp).
# ════════════════════════════════════════════════════════════

def normalize_by_length(entropy_value, n_tokens):
    """Divide an entropy value by the average token count."""
    avg_t = np.mean(n_tokens)
    return entropy_value / max(avg_t, 1)


# ── Verify SE <= PE ────────────────────────────────────────
test_lp = [-50.0, -52.0, -51.0, -49.0, -53.0]
test_cl_1 = [[0,1,2,3,4]]  # all same cluster
test_cl_5 = [[0],[1],[2],[3],[4]]  # all different
pe = predictive_entropy(test_lp)
se_1 = semantic_entropy(test_cl_1, test_lp)
se_5 = semantic_entropy(test_cl_5, test_lp)
dse_1 = discrete_semantic_entropy(test_cl_1, 5)
dse_5 = discrete_semantic_entropy(test_cl_5, 5)
print(f"PE  = {pe:.4f}")
print(f"SE  (1 cluster) = {se_1:.4f}  {'✓ SE<=PE' if se_1 <= pe + 1e-10 else '✗ BUG'}")
print(f"SE  (5 clusters) = {se_5:.4f}  {'✓ SE<=PE' if se_5 <= pe + 1e-10 else '✗ BUG'}  {'✓ SE=PE' if abs(se_5 - pe) < 1e-10 else ''}")
print(f"DSE (1 cluster) = {dse_1:.4f}")
print(f"DSE (5 clusters) = {dse_5:.4f}")
print(f"Gap PE-SE (1 cluster) = {pe - se_1:.4f}  (= phrasing uncertainty removed)")
# Out:
# PE  = 51.0000
# SE  (1 cluster) = 48.5481  ✓ SE<=PE
# SE  (5 clusters) = 51.0000  ✓ SE<=PE  ✓ SE=PE
# DSE (1 cluster) = 0.0000
# DSE (5 clusters) = 1.6094
# Gap PE-SE (1 cluster) = 2.4519  (= phrasing uncertainty removed)

# %% [markdown]
# ## 8b. JSON → natural language conversion
#
# **Why this is needed:** Kuhn's semantic entropy relies on NLI to compare responses. NLI works on natural language, not JSON. When two responses contain the same mitigations in different JSON formatting, NLI sees "entailment" and collapses them into one cluster — even if the actual mitigation sets or priority orderings differ.
#
# **What the conversion does:** parses each JSON response and produces a ranked sentence like:
#
# ```
# 1. Implement Session Expiration, 2. Use Secure Cookies, 3. Session Regeneration
# ```
#
# Now NLI can detect that two responses with different mitigations at priority 1 are not equivalent, and that different ordering constitutes a meaningful difference.
#
# The parser has four fallback levels: clean JSON parse → extract `{...}` block → regex name/priority extraction → stripped-text fallback. This handles DeepSeek's varied output formats (code fences, trailing text, truncated JSON).

# %%
import re

def json_to_natural_language(raw_response):
    """
    Parse a JSON mitigation response and convert it to a natural language
    sentence that preserves both the mitigation SET and the PRIORITY ORDER.

    Example output:
      "1. Implement Session Expiration, 2. Use Secure Cookies, 3. Enforce
       Session Regeneration, 4. Validate Session Credentials"

    If JSON parsing fails, tries progressively more aggressive extraction.
    """
    import json as _json

    text = raw_response.strip()

    # ── Attempt 1: strip markdown fences (greedy, handles multiple ```) ──
    cleaned = re.sub(r'^```[a-zA-Z]*\s*\n?', '', text)
    cleaned = re.sub(r'\n?\s*```\s*$', '', cleaned)
    cleaned = cleaned.strip()

    # ── Attempt 2: extract first { ... } block with regex ──
    def try_parse(s):
        try:
            data = _json.loads(s)
            mitigations = data.get('mitigations', [])
            if mitigations:
                mitigations = sorted(mitigations, key=lambda m: m.get('priority', 999))
                parts = [f"{m.get('priority', i+1)}. {m['name']}" for i, m in enumerate(mitigations)]
                return ', '.join(parts)
        except (ValueError, TypeError, KeyError, AttributeError):
            pass
        return None

    # Try the cleaned text directly
    result = try_parse(cleaned)
    if result:
        return result

    # Try extracting the outermost { ... } from anywhere in the text
    brace_match = re.search(r'(\{.*\})', text, re.DOTALL)
    if brace_match:
        result = try_parse(brace_match.group(1))
        if result:
            return result

    # ── Attempt 3: regex extraction of name/priority pairs ──
    names = re.findall(r'"name"\s*:\s*"([^"]+)"', text)
    priorities = re.findall(r'"priority"\s*:\s*(\d+)', text)
    if names:
        if priorities and len(priorities) == len(names):
            pairs = sorted(zip([int(p) for p in priorities], names))
            return ', '.join([f"{p}. {n}" for p, n in pairs])
        else:
            return ', '.join([f"{i+1}. {n}" for i, n in enumerate(names)])

    # ── Attempt 4: last resort — strip JSON syntax ──
    fallback = re.sub(r'[{}\[\]",:]+', ' ', text)
    fallback = re.sub(r'\s+', ' ', fallback).strip()
    return fallback if fallback else text


# ── Quick tests (verifies all parsing paths) ──
tests = [
    '{"mitigations": [{"name": "Session Expiration", "priority": 2}, {"name": "Secure Cookies", "priority": 1}]}',
    '```json\n{"mitigations": [{"name": "Session Expiration", "priority": 2}, {"name": "Secure Cookies", "priority": 1}]}\n```',
    '```json\n{"mitigations": [{"name": "A", "priority": 1}, {"name": "B", "priority": 2}, {"name": "C", "pri',
]
for t in tests:
    nl = json_to_natural_language(t)
    print(f"IN:  {t[:70]}...")
    print(f"OUT: {nl}\n")
# Out:
# IN:  {"mitigations": [{"name": "Session Expiration", "priority": 2}, {"name...
# OUT: 1. Secure Cookies, 2. Session Expiration
#
# IN:  ```json
# {"mitigations": [{"name": "Session Expiration", "priority": 2}...
# OUT: 1. Secure Cookies, 2. Session Expiration
#
# IN:  ```json
# {"mitigations": [{"name": "A", "priority": 1}, {"name": "B", "...
# OUT: 1. A, 2. B, 3. C

# %% [markdown]
# ## 9. Run experiment
#
# For each attack: sample $M$ responses with log-probs → convert JSON to natural language → cluster with NLI → compute PE, DSE, SE → length-normalize PE and SE.
#
# Results are checkpointed every 10 attacks to avoid losing progress on long runs.

# %%
results = []

for idx, a in enumerate(attacks):
    prompt = build_prompt(a["attack"], a["mitigations"])
    print(f"\n[{idx+1}/{len(attacks)}] {a['attack']}")

    samples = sample_with_logprobs(prompt)
    responses_raw = [s["text"] for s in samples]
    log_probs = [s["log_prob"] for s in samples]
    n_tokens = [s["n_tokens"] for s in samples]

    # Convert JSON → natural language for clustering
    responses_nl = [json_to_natural_language(r) for r in responses_raw]

    # Clustering on natural language versions
    cl_cosine = cluster_by_cosine(responses_nl)
    cl_nli = cluster_by_nli(responses_nl)

    # Three entropy metrics
    pe  = predictive_entropy(log_probs)
    dse = discrete_semantic_entropy(cl_nli, M)
    se  = semantic_entropy(cl_nli, log_probs)

    # Length-normalized versions (comparable across attacks)
    pe_norm = normalize_by_length(pe, n_tokens)
    se_norm = normalize_by_length(se, n_tokens)

    print(f"  PE={pe_norm:.4f}  DSE={dse:.4f}  SE={se_norm:.4f}  ({len(cl_nli)}cl, {np.mean(n_tokens):.0f}tok)")

    results.append({
        "attack": a["attack"],
        "pe": round(pe, 8),
        "dse": round(dse, 8),
        "se": round(se, 8),
        "pe_norm": round(pe_norm, 8),
        "se_norm": round(se_norm, 8),
        "clusters_nli": len(cl_nli),
        "clusters_cosine": len(cl_cosine),
        "avg_tokens": round(np.mean(n_tokens), 1),
        "log_probs": log_probs,
        "n_tokens": n_tokens,
        "responses": responses_raw,
        "responses_nl": responses_nl,
    })

    if (idx + 1) % 10 == 0:
        pd.DataFrame(results).drop(
            columns=["log_probs", "n_tokens", "responses", "responses_nl"], errors="ignore"
        ).to_csv("entropy_checkpoint.csv", index=False)
        print(f"  [checkpoint saved]")

df = pd.DataFrame(results)
print(f"\nDone. {len(df)} attacks processed.")
# Out:
# [1/110] Session Credential Falsification through Manipulation
#     sample 1/8  (log_prob=-106.8, tokens=233)
#     sample 2/8  (log_prob=-51.5, tokens=187)
#     sample 3/8  (log_prob=-69.9, tokens=244)
#     sample 4/8  (log_prob=-69.5, tokens=263)
#     sample 5/8  (log_prob=-78.6, tokens=202)
#     sample 6/8  (log_prob=-62.2, tokens=258)
#     sample 7/8  (log_prob=-63.7, tokens=178)
#     sample 8/8  (log_prob=-70.5, tokens=160)
#   PE=0.3320  DSE=2.0794  SE=0.3320  (8cl, 216tok)
#
# [2/110] Session Credential Falsification through Prediction
#     sample 1/8  (log_prob=-12.4, tokens=162)
#     sample 2/8  (log_prob=-5.1, tokens=176)
#     sample 3/8  (log_prob=-2.7, tokens=175)
#     sample 4/8  (log_prob=-12.5, tokens=175)
#     sample 5/8  (log_prob=-2.7, tokens=175)
#     sample 6/8  (log_prob=-9.7, tokens=176)
#     sample 7/8  (log_prob=-3.0, tokens=176)
#     sample 8/8  (log_prob=-8.3, tokens=177)
#   PE=0.0406  DSE=0.3768  SE=0.0175  (2cl, 174tok)
#
# [3/110] Session Sidejacking
#     sample 1/8  (log_prob=-12.4, tokens=87)
#     sample 2/8  (log_prob=-7.6, tokens=91)
#     sample 3/8  (log_prob=-9.4, tokens=97)
#     sample 4/8  (log_prob=-10.9, tokens=113)
#     sample 5/8  (log_prob=-7.6, tokens=91)
#     sample 6/8  (log_prob=-13.1, tokens=88)
#     sample 7/8  (log_prob=-20.4, tokens=80)
#     sample 8/8  (log_prob=-13.5, tokens=111)
#   PE=0.1252  DSE=1.9062  SE=0.1146  (7cl, 95tok)
#
# [4/110] Cross Site Tracing
#     sample 1/8  (log_prob=-7.1, tokens=61)
#     sample 2/8  (log_prob=-4.9, tokens=64)
#     sample 3/8  (log_prob=-4.2, tokens=70)
#     sample 4/8  (log_prob=-17.0, tokens=89)
#     sample 5/8  (log_prob=-5.6, tokens=68)
#     sample 6/8  (log_prob=-7.1, tokens=51)
#     sample 7/8  (log_prob=-15.5, tokens=54)
#     sample 8/8  (log_prob=-5.5, tokens=62)
#   PE=0.1287  DSE=1.5596  SE=0.1168  (5cl, 65tok)
#
# [5/110] Reusing Session IDs (aka Session Replay)
#     sample 1/8  (log_prob=-6.7, tokens=166)
#     sample 2/8  (log_prob=-10.3, tokens=190)
#     sample 3/8  (log_prob=-11.1, tokens=209)
#     sample 4/8  (log_prob=-11.1, tokens=198)
#     sample 5/8  (log_prob=-7.8, tokens=221)
#     sample 6/8  (log_prob=-13.0, tokens=191)
#     sample 7/8  (log_prob=-8.2, tokens=171)
#     sample 8/8  (log_prob=-8.7, tokens=172)
#   PE=0.0507  DSE=0.9003  SE=0.0396  (3cl, 190tok)
#
# [6/110] Session Fixation
#     sample 1/8  (log_prob=-4.4, tokens=106)
#     sample 2/8  (log_prob=-2.9, tokens=102)
#     sample 3/8  (log_prob=-41.1, tokens=202)
#     sample 4/8  (log_prob=-4.4, tokens=106)
#     sample 5/8  (log_prob=-4.4, tokens=106)
#     sample 6/8  (log_prob=-5.2, tokens=93)
#     sample 7/8  (log_prob=-4.4, tokens=106)
#     sample 8/8  (log_prob=-5.1, tokens=105)
#   PE=0.0777  DSE=0.3768  SE=0.0606  (2cl, 116tok)
#
# [7/110] Cross Site Identification
#     sample 1/8  (log_prob=-11.4, tokens=79)
#     sample 2/8  (log_prob=-26.7, tokens=80)
#     sample 3/8  (log_prob=-13.3, tokens=70)
#     sample 4/8  (log_prob=-6.9, tokens=79)
#     sample 5/8  (log_prob=-12.8, tokens=68)
#     sample 6/8  (log_prob=-11.2, tokens=75)
#     sample 7/8  (log_prob=-26.2, tokens=111)
#     sample 8/8  (log_prob=-48.5, tokens=218)
#   PE=0.2012  DSE=1.0735  SE=0.1741  (4cl, 98tok)
#
# [8/110] Removal of filters: Input filters, output filters, data masking
#     sample 1/8  (log_prob=-105.3, tokens=290)
#     sample 2/8  (log_prob=-58.3, tokens=199)
#     sample 3/8  (log_prob=-44.1, tokens=238)
#     sample 4/8  (log_prob=-94.9, tokens=241)
#     sample 5/8  (log_prob=-94.0, tokens=201)
#     sample 6/8  (log_prob=-83.7, tokens=235)
#     sample 7/8  (log_prob=-45.1, tokens=195)
#     sample 8/8  (log_prob=-36.4, tokens=223)
#   PE=0.3084  DSE=1.6675  SE=0.2470  (6cl, 228tok)
#
# [9/110] Removing/short-circuiting 'Purse' logic: removing/mutating 'cash' decrements
#     sample 1/8  (log_prob=-137.1, tokens=290)
#     sample 2/8  (log_prob=-32.4, tokens=160)
#     sample 3/8  (log_prob=-52.1, tokens=170)
#     sample 4/8  (log_prob=-62.6, tokens=178)
#     sample 5/8  (log_prob=-48.6, tokens=169)
#     sample 6/8  (log_prob=-52.8, tokens=217)
#     sample 7/8  (log_prob=-73.1, tokens=199)
#     sample 8/8  (log_prob=-25.7, tokens=153)
#   PE=0.3154  DSE=2.0794  SE=0.3154  (8cl, 192tok)
#
# [10/110] Subverting Environment Variable Values
#     sample 1/8  (log_prob=-7.1, tokens=155)
#     sample 2/8  (log_prob=-5.6, tokens=155)
#     sample 3/8  (log_prob=-5.3, tokens=155)
#     sample 4/8  (log_prob=-6.0, tokens=151)
#     sample 5/8  (log_prob=-8.0, tokens=153)
#     sample 6/8  (log_prob=-7.2, tokens=151)
#     sample 7/8  (log_prob=-6.0, tokens=151)
#     sample 8/8  (log_prob=-7.2, tokens=131)
#   PE=0.0436  DSE=0.3768  SE=0.0307  (2cl, 150tok)
#   [checkpoint saved]
#
# [11/110] Manipulating Hidden Fields
#     sample 1/8  (log_prob=-108.3, tokens=198)
#     sample 2/8  (log_prob=-35.0, tokens=176)
#     sample 3/8  (log_prob=-48.1, tokens=149)
#     sample 4/8  (log_prob=-26.7, tokens=140)
#     sample 5/8  (log_prob=-26.9, tokens=154)
#     sample 6/8  (log_prob=-28.4, tokens=143)
#     sample 7/8  (log_prob=-23.1, tokens=163)
#     sample 8/8  (log_prob=-29.7, tokens=113)
#   PE=0.2638  DSE=2.0794  SE=0.2638  (8cl, 154tok)
#
# [12/110] Leveraging Race Conditions via Symbolic Links
#     sample 1/8  (log_prob=-5.7, tokens=120)
#     sample 2/8  (log_prob=-16.8, tokens=102)
#     sample 3/8  (log_prob=-7.3, tokens=110)
#     sample 4/8  (log_prob=-5.1, tokens=110)
#     sample 5/8  (log_prob=-13.0, tokens=132)
#     sample 6/8  (log_prob=-7.8, tokens=133)
#     sample 7/8  (log_prob=-4.0, tokens=107)
#     sample 8/8  (log_prob=-5.6, tokens=105)
#   PE=0.0710  DSE=0.9743  SE=0.0519  (3cl, 115tok)
#
# [13/110] Fuzzing for application mapping
#     sample 1/8  (log_prob=-15.3, tokens=230)
#     sample 2/8  (log_prob=-2.8, tokens=255)
#     sample 3/8  (log_prob=-6.9, tokens=218)
#     sample 4/8  (log_prob=-6.1, tokens=219)
#     sample 5/8  (log_prob=-5.4, tokens=254)
#     sample 6/8  (log_prob=-2.8, tokens=255)
#     sample 7/8  (log_prob=-5.7, tokens=208)
#     sample 8/8  (log_prob=-7.6, tokens=254)
#   PE=0.0277  DSE=1.2130  SE=0.0214  (4cl, 237tok)
#
# [14/110] Load Value Injection
#     sample 1/8  (log_prob=-5.7, tokens=79)
#     sample 2/8  (log_prob=-7.1, tokens=75)
#     sample 3/8  (log_prob=-4.0, tokens=79)
#     sample 4/8  (log_prob=-5.4, tokens=78)
#     sample 5/8  (log_prob=-6.5, tokens=74)
#     sample 6/8  (log_prob=-1.9, tokens=79)
#     sample 7/8  (log_prob=-1.9, tokens=79)
#     sample 8/8  (log_prob=-4.0, tokens=79)
#   PE=0.0589  DSE=0.0000  SE=0.0141  (1cl, 78tok)
#
# [15/110] Transaction or Event Tampering via Application API Manipulation
#     sample 1/8  (log_prob=-125.6, tokens=265)
#     sample 2/8  (log_prob=-34.6, tokens=180)
#     sample 3/8  (log_prob=-47.2, tokens=175)
#     sample 4/8  (log_prob=-57.3, tokens=200)
#     sample 5/8  (log_prob=-34.9, tokens=174)
#     sample 6/8  (log_prob=-56.9, tokens=243)
#     sample 7/8  (log_prob=-97.1, tokens=260)
#     sample 8/8  (log_prob=-108.2, tokens=234)
#   PE=0.3246  DSE=1.9062  SE=0.3119  (7cl, 216tok)
#
# [16/110] Content Spoofing Via Application API Manipulation
#     sample 1/8  (log_prob=-44.9, tokens=235)
#     sample 2/8  (log_prob=-47.8, tokens=213)
#     sample 3/8  (log_prob=-54.6, tokens=185)
#     sample 4/8  (log_prob=-46.7, tokens=225)
#     sample 5/8  (log_prob=-60.8, tokens=259)
#     sample 6/8  (log_prob=-57.0, tokens=188)
#     sample 7/8  (log_prob=-42.0, tokens=236)
#     sample 8/8  (log_prob=-30.8, tokens=177)
#   PE=0.2239  DSE=1.9062  SE=0.2164  (7cl, 215tok)
#
# [17/110] Navigation Remapping To Propagate Malicious Content
#     sample 1/8  (log_prob=-38.5, tokens=145)
#     sample 2/8  (log_prob=-50.4, tokens=149)
#     sample 3/8  (log_prob=-81.9, tokens=287)
#     sample 4/8  (log_prob=-83.2, tokens=196)
#     sample 5/8  (log_prob=-51.3, tokens=225)
#     sample 6/8  (log_prob=-42.0, tokens=228)
#     sample 7/8  (log_prob=-49.4, tokens=215)
#     sample 8/8  (log_prob=-64.9, tokens=195)
#   PE=0.2815  DSE=2.0794  SE=0.2815  (8cl, 205tok)
#
# [18/110] Application API Button Hijacking
#     sample 1/8  (log_prob=-34.2, tokens=167)
#     sample 2/8  (log_prob=-86.1, tokens=216)
#     sample 3/8  (log_prob=-89.1, tokens=200)
#     sample 4/8  (log_prob=-73.0, tokens=217)
#     sample 5/8  (log_prob=-54.4, tokens=243)
#     sample 6/8  (log_prob=-32.9, tokens=164)
#     sample 7/8  (log_prob=-61.9, tokens=214)
#     sample 8/8  (log_prob=-52.1, tokens=251)
#   PE=0.2892  DSE=1.9062  SE=0.2877  (7cl, 209tok)
#
# [19/110] Dictionary-based Password Attack
#     sample 1/8  (log_prob=-40.0, tokens=120)
#     sample 2/8  (log_prob=-3.9, tokens=93)
#     sample 3/8  (log_prob=-3.4, tokens=93)
#     sample 4/8  (log_prob=-5.3, tokens=121)
#     sample 5/8  (log_prob=-8.8, tokens=121)
#     sample 6/8  (log_prob=-8.8, tokens=121)
#     sample 7/8  (log_prob=-5.2, tokens=69)
#     sample 8/8  (log_prob=-32.7, tokens=191)
#   PE=0.1164  DSE=1.2555  SE=0.1045  (4cl, 116tok)
#
# [20/110] Rainbow Table Password Cracking
#     sample 1/8  (log_prob=-48.7, tokens=196)
#     sample 2/8  (log_prob=-26.3, tokens=152)
#     sample 3/8  (log_prob=-44.3, tokens=173)
#     sample 4/8  (log_prob=-21.5, tokens=106)
#     sample 5/8  (log_prob=-39.1, tokens=127)
#     sample 6/8  (log_prob=-15.5, tokens=122)
#     sample 7/8  (log_prob=-18.3, tokens=104)
#     sample 8/8  (log_prob=-35.5, tokens=146)
#   PE=0.2213  DSE=2.0794  SE=0.2213  (8cl, 141tok)
#   [checkpoint saved]
#
# [21/110] Password Spraying
#     sample 1/8  (log_prob=-5.8, tokens=108)
#     sample 2/8  (log_prob=-13.5, tokens=86)
#     sample 3/8  (log_prob=-6.0, tokens=95)
#     sample 4/8  (log_prob=-11.4, tokens=132)
#     sample 5/8  (log_prob=-5.0, tokens=104)
#     sample 6/8  (log_prob=-7.6, tokens=104)
#     sample 7/8  (log_prob=-6.0, tokens=95)
#     sample 8/8  (log_prob=-21.3, tokens=109)
#   PE=0.0920  DSE=0.9003  SE=0.0688  (3cl, 104tok)
#
# [22/110] Try Common or Default Usernames and Passwords
#     sample 1/8  (log_prob=-11.2, tokens=126)
#     sample 2/8  (log_prob=-5.3, tokens=169)
#     sample 3/8  (log_prob=-9.6, tokens=169)
#     sample 4/8  (log_prob=-5.3, tokens=169)
#     sample 5/8  (log_prob=-5.7, tokens=169)
#     sample 6/8  (log_prob=-4.4, tokens=165)
#     sample 7/8  (log_prob=-5.7, tokens=165)
#     sample 8/8  (log_prob=-18.7, tokens=146)
#   PE=0.0515  DSE=0.3768  SE=0.0282  (2cl, 160tok)
#
# [23/110] Root/Jailbreak Detection Evasion via Debugging
#     sample 1/8  (log_prob=-55.7, tokens=130)
#     sample 2/8  (log_prob=-36.0, tokens=120)
#     sample 3/8  (log_prob=-39.9, tokens=107)
#     sample 4/8  (log_prob=-18.8, tokens=118)
#     sample 5/8  (log_prob=-39.2, tokens=112)
#     sample 6/8  (log_prob=-17.1, tokens=118)
#     sample 7/8  (log_prob=-50.1, tokens=158)
#     sample 8/8  (log_prob=-24.4, tokens=122)
#   PE=0.2855  DSE=2.0794  SE=0.2855  (8cl, 123tok)
#
# [24/110] Escaping a Sandbox by Calling Code in Another Language
#     sample 1/8  (log_prob=-4.8, tokens=140)
#     sample 2/8  (log_prob=-5.2, tokens=106)
#     sample 3/8  (log_prob=-13.8, tokens=125)
#     sample 4/8  (log_prob=-5.1, tokens=130)
#     sample 5/8  (log_prob=-5.7, tokens=136)
#     sample 6/8  (log_prob=-30.9, tokens=118)
#     sample 7/8  (log_prob=-5.1, tokens=130)
#     sample 8/8  (log_prob=-5.4, tokens=116)
#   PE=0.0759  DSE=0.9743  SE=0.0594  (3cl, 125tok)
#
# [25/110] Detect Unpublicized Web Pages
#     sample 1/8  (log_prob=-94.4, tokens=238)
#     sample 2/8  (log_prob=-33.6, tokens=157)
#     sample 3/8  (log_prob=-65.2, tokens=221)
#     sample 4/8  (log_prob=-33.9, tokens=132)
#     sample 5/8  (log_prob=-70.9, tokens=235)
#     sample 6/8  (log_prob=-55.0, tokens=188)
#     sample 7/8  (log_prob=-118.1, tokens=233)
#     sample 8/8  (log_prob=-47.8, tokens=226)
#   PE=0.3184  DSE=2.0794  SE=0.3184  (8cl, 204tok)
#
# [26/110] Detect Unpublicized Web Services
#     sample 1/8  (log_prob=-89.7, tokens=257)
#     sample 2/8  (log_prob=-68.7, tokens=189)
#     sample 3/8  (log_prob=-93.5, tokens=273)
#     sample 4/8  (log_prob=-38.3, tokens=189)
#     sample 5/8  (log_prob=-59.0, tokens=225)
#     sample 6/8  (log_prob=-53.9, tokens=211)
#     sample 7/8  (log_prob=-40.1, tokens=204)
#     sample 8/8  (log_prob=-45.5, tokens=227)
#   PE=0.2753  DSE=1.9062  SE=0.2622  (7cl, 222tok)
#
# [27/110] Screen Temporary Files for Sensitive Information
#     sample 1/8  (log_prob=-52.3, tokens=158)
#     sample 2/8  (log_prob=-50.0, tokens=157)
#     sample 3/8  (log_prob=-76.5, tokens=211)
#     sample 4/8  (log_prob=-100.5, tokens=201)
#     sample 5/8  (log_prob=-55.3, tokens=215)
#     sample 6/8  (log_prob=-60.2, tokens=186)
#     sample 7/8  (log_prob=-48.0, tokens=190)
#     sample 8/8  (log_prob=-65.1, tokens=206)
#   PE=0.3332  DSE=1.7329  SE=0.2961  (6cl, 190tok)
#
# [28/110] Collect Data from Clipboard
#     sample 1/8  (log_prob=-9.3, tokens=64)
#     sample 2/8  (log_prob=-20.7, tokens=105)
#     sample 3/8  (log_prob=-11.2, tokens=59)
#     sample 4/8  (log_prob=-9.0, tokens=70)
#     sample 5/8  (log_prob=-11.1, tokens=62)
#     sample 6/8  (log_prob=-36.5, tokens=130)
#     sample 7/8  (log_prob=-11.0, tokens=61)
#     sample 8/8  (log_prob=-12.2, tokens=60)
#   PE=0.1981  DSE=1.4942  SE=0.1885  (5cl, 76tok)
#
# [29/110] Collect Data from Registries
#     sample 1/8  (log_prob=-25.6, tokens=119)
#     sample 2/8  (log_prob=-79.9, tokens=178)
#     sample 3/8  (log_prob=-84.9, tokens=177)
#     sample 4/8  (log_prob=-33.4, tokens=146)
#     sample 5/8  (log_prob=-39.7, tokens=145)
#     sample 6/8  (log_prob=-240.2, tokens=357)
#     sample 7/8  (log_prob=-26.7, tokens=148)
#     sample 8/8  (log_prob=-21.9, tokens=94)
#   PE=0.4049  DSE=2.0794  SE=0.4049  (8cl, 170tok)
#
# [30/110] Collect Data from Screen Capture
#     sample 1/8  (log_prob=-10.6, tokens=60)
#     sample 2/8  (log_prob=-24.5, tokens=121)
#     sample 3/8  (log_prob=-46.0, tokens=138)
#     sample 4/8  (log_prob=-20.6, tokens=119)
#     sample 5/8  (log_prob=-15.0, tokens=79)
#     sample 6/8  (log_prob=-15.3, tokens=93)
#     sample 7/8  (log_prob=-25.3, tokens=110)
#     sample 8/8  (log_prob=-58.3, tokens=152)
#   PE=0.2470  DSE=1.9062  SE=0.2406  (7cl, 109tok)
#   [checkpoint saved]
#
# [31/110] Directory Indexing
#     sample 1/8  (log_prob=-9.2, tokens=103)
#     sample 2/8  (log_prob=-8.1, tokens=103)
#     sample 3/8  (log_prob=-17.5, tokens=102)
#     sample 4/8  (log_prob=-4.2, tokens=80)
#     sample 5/8  (log_prob=-7.2, tokens=99)
#     sample 6/8  (log_prob=-11.0, tokens=82)
#     sample 7/8  (log_prob=-4.2, tokens=80)
#     sample 8/8  (log_prob=-7.5, tokens=103)
#   PE=0.0916  DSE=0.5623  SE=0.0600  (2cl, 94tok)
#
# [32/110] Fuzzing for application mapping
#     sample 1/8  (log_prob=-4.4, tokens=255)
#     sample 2/8  (log_prob=-5.4, tokens=255)
#     sample 3/8  (log_prob=-6.8, tokens=255)
#     sample 4/8  (log_prob=-6.7, tokens=168)
#     sample 5/8  (log_prob=-3.7, tokens=219)
#     sample 6/8  (log_prob=-6.9, tokens=218)
#     sample 7/8  (log_prob=-9.6, tokens=243)
#     sample 8/8  (log_prob=-6.1, tokens=219)
#   PE=0.0271  DSE=1.2555  SE=0.0214  (4cl, 229tok)
#
# [33/110] Fuzzing for garnering other adjacent user/sensitive data
#     sample 1/8  (log_prob=-55.7, tokens=192)
#     sample 2/8  (log_prob=-51.4, tokens=204)
#     sample 3/8  (log_prob=-37.0, tokens=203)
#     sample 4/8  (log_prob=-36.4, tokens=178)
#     sample 5/8  (log_prob=-34.7, tokens=203)
#     sample 6/8  (log_prob=-25.7, tokens=203)
#     sample 7/8  (log_prob=-35.2, tokens=163)
#     sample 8/8  (log_prob=-27.7, tokens=203)
#   PE=0.1962  DSE=1.9062  SE=0.1948  (7cl, 194tok)
#
# [34/110] Cross-Domain Search Timing
#     sample 1/8  (log_prob=-11.0, tokens=63)
#     sample 2/8  (log_prob=-16.9, tokens=62)
#     sample 3/8  (log_prob=-104.5, tokens=173)
#     sample 4/8  (log_prob=-12.3, tokens=71)
#     sample 5/8  (log_prob=-22.4, tokens=54)
#     sample 6/8  (log_prob=-10.3, tokens=58)
#     sample 7/8  (log_prob=-12.6, tokens=70)
#     sample 8/8  (log_prob=-65.5, tokens=129)
#   PE=0.3758  DSE=1.6675  SE=0.3544  (6cl, 85tok)
#
# [35/110] WSDL Scanning
#     sample 1/8  (log_prob=-15.1, tokens=153)
#     sample 2/8  (log_prob=-10.6, tokens=148)
#     sample 3/8  (log_prob=-18.4, tokens=154)
#     sample 4/8  (log_prob=-11.5, tokens=163)
#     sample 5/8  (log_prob=-14.3, tokens=140)
#     sample 6/8  (log_prob=-23.9, tokens=140)
#     sample 7/8  (log_prob=-13.8, tokens=120)
#     sample 8/8  (log_prob=-14.2, tokens=159)
#   PE=0.1035  DSE=1.0735  SE=0.0915  (4cl, 147tok)
#
# [36/110] Probe iOS Screenshots
#     sample 1/8  (log_prob=-26.3, tokens=42)
#     sample 2/8  (log_prob=-36.1, tokens=102)
#     sample 3/8  (log_prob=-26.7, tokens=98)
#     sample 4/8  (log_prob=-23.4, tokens=117)
#     sample 5/8  (log_prob=-35.9, tokens=125)
#     sample 6/8  (log_prob=-40.0, tokens=134)
#     sample 7/8  (log_prob=-22.7, tokens=121)
#     sample 8/8  (log_prob=-37.1, tokens=127)
#   PE=0.2865  DSE=2.0794  SE=0.2865  (8cl, 108tok)
#
# [37/110] Incomplete Data Deletion in a Multi-Tenant Environment
#     sample 1/8  (log_prob=-34.1, tokens=129)
#     sample 2/8  (log_prob=-41.4, tokens=98)
#     sample 3/8  (log_prob=-66.4, tokens=183)
#     sample 4/8  (log_prob=-34.6, tokens=108)
#     sample 5/8  (log_prob=-12.8, tokens=60)
#     sample 6/8  (log_prob=-75.2, tokens=169)
#     sample 7/8  (log_prob=-24.4, tokens=106)
#     sample 8/8  (log_prob=-29.2, tokens=108)
#   PE=0.3309  DSE=1.9062  SE=0.2661  (7cl, 120tok)
#
# [38/110] Probe Audio and Video Peripherals
#     sample 1/8  (log_prob=-45.0, tokens=168)
#     sample 2/8  (log_prob=-47.1, tokens=155)
#     sample 3/8  (log_prob=-34.0, tokens=147)
#     sample 4/8  (log_prob=-42.6, tokens=170)
#     sample 5/8  (log_prob=-8.7, tokens=76)
#     sample 6/8  (log_prob=-59.9, tokens=185)
#     sample 7/8  (log_prob=-38.3, tokens=125)
#     sample 8/8  (log_prob=-35.7, tokens=130)
#   PE=0.2693  DSE=2.0794  SE=0.2693  (8cl, 144tok)
#
# [39/110] Probe System Files
#     sample 1/8  (log_prob=-14.3, tokens=59)
#     sample 2/8  (log_prob=-31.2, tokens=119)
#     sample 3/8  (log_prob=-26.8, tokens=127)
#     sample 4/8  (log_prob=-52.2, tokens=143)
#     sample 5/8  (log_prob=-14.8, tokens=57)
#     sample 6/8  (log_prob=-38.3, tokens=177)
#     sample 7/8  (log_prob=-33.6, tokens=144)
#     sample 8/8  (log_prob=-45.9, tokens=121)
#   PE=0.2716  DSE=2.0794  SE=0.2716  (8cl, 118tok)
#
# [40/110] Capture Credentials via Keylogger
#     sample 1/8  (log_prob=-39.9, tokens=131)
#     sample 2/8  (log_prob=-31.0, tokens=128)
#     sample 3/8  (log_prob=-32.2, tokens=164)
#     sample 4/8  (log_prob=-32.0, tokens=154)
#     sample 5/8  (log_prob=-114.9, tokens=175)
#     sample 6/8  (log_prob=-38.5, tokens=131)
#     sample 7/8  (log_prob=-38.9, tokens=156)
#     sample 8/8  (log_prob=-85.2, tokens=169)
#   PE=0.3416  DSE=1.6675  SE=0.3327  (6cl, 151tok)
#   [checkpoint saved]
#
# [41/110] Sniffing Network Traffic
#     sample 1/8  (log_prob=-8.0, tokens=76)
#     sample 2/8  (log_prob=-10.1, tokens=56)
#     sample 3/8  (log_prob=-46.3, tokens=193)
#     sample 4/8  (log_prob=-27.9, tokens=110)
#     sample 5/8  (log_prob=-9.4, tokens=73)
#     sample 6/8  (log_prob=-8.8, tokens=69)
#     sample 7/8  (log_prob=-6.5, tokens=77)
#     sample 8/8  (log_prob=-18.4, tokens=59)
#   PE=0.1900  DSE=1.6675  SE=0.1828  (6cl, 89tok)
#
# [42/110] Utilizing REST's Trust in the System Resource to Obtain Sensitive Data
#     sample 1/8  (log_prob=-4.8, tokens=95)
#     sample 2/8  (log_prob=-6.1, tokens=80)
#     sample 3/8  (log_prob=-6.9, tokens=99)
#     sample 4/8  (log_prob=-6.9, tokens=99)
#     sample 5/8  (log_prob=-10.4, tokens=80)
#     sample 6/8  (log_prob=-7.9, tokens=84)
#     sample 7/8  (log_prob=-37.5, tokens=188)
#     sample 8/8  (log_prob=-13.3, tokens=121)
#   PE=0.1110  DSE=1.0735  SE=0.0982  (4cl, 106tok)
#
# [43/110] Sniff Application Code
#     sample 1/8  (log_prob=-8.3, tokens=95)
#     sample 2/8  (log_prob=-9.2, tokens=94)
#     sample 3/8  (log_prob=-6.9, tokens=103)
#     sample 4/8  (log_prob=-6.9, tokens=99)
#     sample 5/8  (log_prob=-10.9, tokens=95)
#     sample 6/8  (log_prob=-17.9, tokens=116)
#     sample 7/8  (log_prob=-9.8, tokens=96)
#     sample 8/8  (log_prob=-9.8, tokens=96)
#   PE=0.1003  DSE=0.9743  SE=0.0757  (3cl, 99tok)
#
# [44/110] Android Activity Hijack
#     sample 1/8  (log_prob=-14.2, tokens=63)
#     sample 2/8  (log_prob=-19.2, tokens=85)
#     sample 3/8  (log_prob=-15.2, tokens=82)
#     sample 4/8  (log_prob=-13.8, tokens=58)
#     sample 5/8  (log_prob=-10.6, tokens=90)
#     sample 6/8  (log_prob=-10.1, tokens=116)
#     sample 7/8  (log_prob=-14.0, tokens=78)
#     sample 8/8  (log_prob=-9.3, tokens=81)
#   PE=0.1629  DSE=1.9062  SE=0.1603  (7cl, 82tok)
#
# [45/110] Probe Audio and Video Peripherals
#     sample 1/8  (log_prob=-74.7, tokens=225)
#     sample 2/8  (log_prob=-44.5, tokens=107)
#     sample 3/8  (log_prob=-50.0, tokens=126)
#     sample 4/8  (log_prob=-28.1, tokens=119)
#     sample 5/8  (log_prob=-37.2, tokens=158)
#     sample 6/8  (log_prob=-69.8, tokens=187)
#     sample 7/8  (log_prob=-46.1, tokens=157)
#     sample 8/8  (log_prob=-26.1, tokens=113)
#   PE=0.3159  DSE=2.0794  SE=0.3159  (8cl, 149tok)
#
# [46/110] Restful Privilege Elevation
#     sample 1/8  (log_prob=-4.9, tokens=110)
#     sample 2/8  (log_prob=-4.8, tokens=106)
#     sample 3/8  (log_prob=-4.9, tokens=110)
#     sample 4/8  (log_prob=-4.8, tokens=106)
#     sample 5/8  (log_prob=-4.8, tokens=106)
#     sample 6/8  (log_prob=-4.8, tokens=106)
#     sample 7/8  (log_prob=-4.9, tokens=110)
#     sample 8/8  (log_prob=-4.9, tokens=110)
#   PE=0.0449  DSE=0.0000  SE=0.0257  (1cl, 108tok)
#
# [47/110] Create files with the same name as files protected with a higher classification
#     sample 1/8  (log_prob=-60.9, tokens=217)
#     sample 2/8  (log_prob=-55.6, tokens=192)
#     sample 3/8  (log_prob=-92.5, tokens=200)
#     sample 4/8  (log_prob=-79.3, tokens=222)
#     sample 5/8  (log_prob=-53.1, tokens=223)
#     sample 6/8  (log_prob=-52.3, tokens=144)
#     sample 7/8  (log_prob=-66.4, tokens=181)
#     sample 8/8  (log_prob=-43.4, tokens=204)
#   PE=0.3180  DSE=1.9062  SE=0.2870  (7cl, 198tok)
#
# [48/110] Force Use of Corrupted Files
#     sample 1/8  (log_prob=-54.6, tokens=207)
#     sample 2/8  (log_prob=-65.9, tokens=199)
#     sample 3/8  (log_prob=-85.8, tokens=219)
#     sample 4/8  (log_prob=-81.4, tokens=234)
#     sample 5/8  (log_prob=-60.5, tokens=258)
#     sample 6/8  (log_prob=-72.6, tokens=218)
#     sample 7/8  (log_prob=-60.4, tokens=157)
#     sample 8/8  (log_prob=-59.0, tokens=197)
#   PE=0.3199  DSE=1.9062  SE=0.3075  (7cl, 211tok)
#
# [49/110] Modify Shared File
#     sample 1/8  (log_prob=-2.5, tokens=102)
#     sample 2/8  (log_prob=-7.7, tokens=102)
#     sample 3/8  (log_prob=-4.5, tokens=102)
#     sample 4/8  (log_prob=-4.5, tokens=102)
#     sample 5/8  (log_prob=-4.5, tokens=102)
#     sample 6/8  (log_prob=-9.0, tokens=99)
#     sample 7/8  (log_prob=-7.7, tokens=102)
#     sample 8/8  (log_prob=-8.6, tokens=98)
#   PE=0.0603  DSE=0.0000  SE=0.0208  (1cl, 101tok)
#
# [50/110] Add Malicious File to Shared Webroot
#     sample 1/8  (log_prob=-9.4, tokens=143)
#     sample 2/8  (log_prob=-9.1, tokens=140)
#     sample 3/8  (log_prob=-4.1, tokens=144)
#     sample 4/8  (log_prob=-4.1, tokens=144)
#     sample 5/8  (log_prob=-11.0, tokens=118)
#     sample 6/8  (log_prob=-5.6, tokens=120)
#     sample 7/8  (log_prob=-24.4, tokens=181)
#     sample 8/8  (log_prob=-6.7, tokens=147)
#   PE=0.0654  DSE=0.7356  SE=0.0447  (3cl, 142tok)
#   [checkpoint saved]
#
# [51/110] Replace Binaries
#     sample 1/8  (log_prob=-6.2, tokens=75)
#     sample 2/8  (log_prob=-14.3, tokens=70)
#     sample 3/8  (log_prob=-11.7, tokens=99)
#     sample 4/8  (log_prob=-17.1, tokens=93)
#     sample 5/8  (log_prob=-16.4, tokens=73)
#     sample 6/8  (log_prob=-10.1, tokens=86)
#     sample 7/8  (log_prob=-6.2, tokens=102)
#     sample 8/8  (log_prob=-28.6, tokens=161)
#   PE=0.1457  DSE=2.0794  SE=0.1457  (8cl, 95tok)
#
# [52/110] Upload a Web Shell to a Web Server
#     sample 1/8  (log_prob=-23.3, tokens=95)
#     sample 2/8  (log_prob=-86.5, tokens=512)
#     sample 3/8  (log_prob=-27.9, tokens=81)
#     sample 4/8  (log_prob=-7.3, tokens=104)
#     sample 5/8  (log_prob=-31.2, tokens=193)
#     sample 6/8  (log_prob=-32.7, tokens=178)
#     sample 7/8  (log_prob=-18.4, tokens=87)
#     sample 8/8  (log_prob=-15.2, tokens=108)
#   PE=0.1786  DSE=1.9062  SE=0.1728  (7cl, 170tok)
#
# [53/110] Restful Privilege Elevation
#     sample 1/8  (log_prob=-3.2, tokens=106)
#     sample 2/8  (log_prob=-10.0, tokens=91)
#     sample 3/8  (log_prob=-4.8, tokens=106)
#     sample 4/8  (log_prob=-2.8, tokens=110)
#     sample 5/8  (log_prob=-6.3, tokens=91)
#     sample 6/8  (log_prob=-4.9, tokens=110)
#     sample 7/8  (log_prob=-6.5, tokens=106)
#     sample 8/8  (log_prob=-4.9, tokens=110)
#   PE=0.0523  DSE=0.0000  SE=0.0195  (1cl, 104tok)
#
# [54/110] Exploiting Incorrect Chaining or Granularity of Hardware Debug Components
#     sample 1/8  (log_prob=-7.3, tokens=86)
#     sample 2/8  (log_prob=-24.2, tokens=118)
#     sample 3/8  (log_prob=-9.8, tokens=76)
#     sample 4/8  (log_prob=-5.8, tokens=86)
#     sample 5/8  (log_prob=-3.0, tokens=90)
#     sample 6/8  (log_prob=-16.3, tokens=79)
#     sample 7/8  (log_prob=-9.1, tokens=101)
#     sample 8/8  (log_prob=-3.0, tokens=90)
#   PE=0.1082  DSE=0.7356  SE=0.0659  (3cl, 91tok)
#
# [55/110] Serialized Data External Linking
#     sample 1/8  (log_prob=-44.8, tokens=144)
#     sample 2/8  (log_prob=-32.6, tokens=124)
#     sample 3/8  (log_prob=-27.7, tokens=80)
#     sample 4/8  (log_prob=-50.0, tokens=107)
#     sample 5/8  (log_prob=-50.2, tokens=147)
#     sample 6/8  (log_prob=-19.0, tokens=74)
#     sample 7/8  (log_prob=-75.5, tokens=174)
#     sample 8/8  (log_prob=-63.4, tokens=145)
#   PE=0.3649  DSE=2.0794  SE=0.3649  (8cl, 124tok)
#
# [56/110] Buffer Overflow via Environment Variables
#     sample 1/8  (log_prob=-22.6, tokens=101)
#     sample 2/8  (log_prob=-8.4, tokens=128)
#     sample 3/8  (log_prob=-11.6, tokens=154)
#     sample 4/8  (log_prob=-14.5, tokens=122)
#     sample 5/8  (log_prob=-5.7, tokens=128)
#     sample 6/8  (log_prob=-8.4, tokens=128)
#     sample 7/8  (log_prob=-14.9, tokens=122)
#     sample 8/8  (log_prob=-15.2, tokens=108)
#   PE=0.1023  DSE=1.6675  SE=0.0965  (6cl, 124tok)
#
# [57/110] Client-side Injection-induced Buffer Overflow
#     sample 1/8  (log_prob=-30.7, tokens=177)
#     sample 2/8  (log_prob=-27.6, tokens=232)
#     sample 3/8  (log_prob=-31.0, tokens=221)
#     sample 4/8  (log_prob=-25.2, tokens=164)
#     sample 5/8  (log_prob=-35.7, tokens=169)
#     sample 6/8  (log_prob=-28.6, tokens=227)
#     sample 7/8  (log_prob=-14.2, tokens=234)
#     sample 8/8  (log_prob=-75.9, tokens=253)
#   PE=0.1603  DSE=0.9003  SE=0.0898  (3cl, 210tok)
#
# [58/110] Filter Failure through Buffer Overflow
#     sample 1/8  (log_prob=-21.7, tokens=159)
#     sample 2/8  (log_prob=-34.7, tokens=156)
#     sample 3/8  (log_prob=-10.2, tokens=158)
#     sample 4/8  (log_prob=-29.2, tokens=161)
#     sample 5/8  (log_prob=-24.9, tokens=163)
#     sample 6/8  (log_prob=-27.3, tokens=129)
#     sample 7/8  (log_prob=-30.6, tokens=152)
#     sample 8/8  (log_prob=-38.1, tokens=194)
#   PE=0.1704  DSE=1.6675  SE=0.1395  (6cl, 159tok)
#
# [59/110] SOAP Array Overflow
#     sample 1/8  (log_prob=-12.1, tokens=55)
#     sample 2/8  (log_prob=-28.4, tokens=78)
#     sample 3/8  (log_prob=-12.0, tokens=48)
#     sample 4/8  (log_prob=-12.2, tokens=62)
#     sample 5/8  (log_prob=-33.8, tokens=100)
#     sample 6/8  (log_prob=-16.0, tokens=58)
#     sample 7/8  (log_prob=-25.0, tokens=102)
#     sample 8/8  (log_prob=-8.2, tokens=55)
#   PE=0.2646  DSE=1.9062  SE=0.2621  (7cl, 70tok)
#
# [60/110] MIME Conversion
#     sample 1/8  (log_prob=-8.1, tokens=129)
#     sample 2/8  (log_prob=-4.3, tokens=116)
#     sample 3/8  (log_prob=-7.1, tokens=115)
#     sample 4/8  (log_prob=-6.1, tokens=135)
#     sample 5/8  (log_prob=-9.1, tokens=91)
#     sample 6/8  (log_prob=-6.1, tokens=115)
#     sample 7/8  (log_prob=-11.0, tokens=145)
#     sample 8/8  (log_prob=-6.1, tokens=89)
#   PE=0.0618  DSE=0.9003  SE=0.0458  (3cl, 117tok)
#   [checkpoint saved]
#
# [61/110] Overflow Binary Resource File
#     sample 1/8  (log_prob=-9.1, tokens=150)
#     sample 2/8  (log_prob=-5.6, tokens=125)
#     sample 3/8  (log_prob=-7.6, tokens=154)
#     sample 4/8  (log_prob=-8.5, tokens=162)
#     sample 5/8  (log_prob=-4.4, tokens=154)
#     sample 6/8  (log_prob=-4.4, tokens=154)
#     sample 7/8  (log_prob=-4.2, tokens=150)
#     sample 8/8  (log_prob=-4.2, tokens=150)
#   PE=0.0400  DSE=0.0000  SE=0.0187  (1cl, 150tok)
#
# [62/110] Buffer Overflow via Symbolic Links
#     sample 1/8  (log_prob=-20.7, tokens=193)
#     sample 2/8  (log_prob=-18.1, tokens=151)
#     sample 3/8  (log_prob=-27.5, tokens=212)
#     sample 4/8  (log_prob=-20.7, tokens=220)
#     sample 5/8  (log_prob=-16.2, tokens=186)
#     sample 6/8  (log_prob=-22.5, tokens=219)
#     sample 7/8  (log_prob=-30.2, tokens=160)
#     sample 8/8  (log_prob=-27.5, tokens=205)
#   PE=0.1187  DSE=0.3768  SE=0.0904  (2cl, 193tok)
#
# [63/110] Overflow Variables and Tags
#     sample 1/8  (log_prob=-7.3, tokens=156)
#     sample 2/8  (log_prob=-6.2, tokens=152)
#     sample 3/8  (log_prob=-11.8, tokens=127)
#     sample 4/8  (log_prob=-9.9, tokens=180)
#     sample 5/8  (log_prob=-7.7, tokens=152)
#     sample 6/8  (log_prob=-5.3, tokens=143)
#     sample 7/8  (log_prob=-8.8, tokens=157)
#     sample 8/8  (log_prob=-5.3, tokens=143)
#   PE=0.0515  DSE=0.9003  SE=0.0378  (3cl, 151tok)
#
# [64/110] Buffer Overflow via Parameter Expansion
#     sample 1/8  (log_prob=-44.6, tokens=142)
#     sample 2/8  (log_prob=-73.5, tokens=116)
#     sample 3/8  (log_prob=-34.8, tokens=107)
#     sample 4/8  (log_prob=-17.4, tokens=135)
#     sample 5/8  (log_prob=-26.1, tokens=150)
#     sample 6/8  (log_prob=-28.7, tokens=138)
#     sample 7/8  (log_prob=-37.3, tokens=136)
#     sample 8/8  (log_prob=-20.7, tokens=150)
#   PE=0.2636  DSE=1.9062  SE=0.2567  (7cl, 134tok)
#
# [65/110] String Format Overflow in syslog()
#     sample 1/8  (log_prob=-21.5, tokens=111)
#     sample 2/8  (log_prob=-34.5, tokens=162)
#     sample 3/8  (log_prob=-24.7, tokens=143)
#     sample 4/8  (log_prob=-21.6, tokens=97)
#     sample 5/8  (log_prob=-18.7, tokens=111)
#     sample 6/8  (log_prob=-19.7, tokens=133)
#     sample 7/8  (log_prob=-16.2, tokens=109)
#     sample 8/8  (log_prob=-48.5, tokens=153)
#   PE=0.2015  DSE=1.9062  SE=0.1983  (7cl, 127tok)
#
# [66/110] Buffer Overflow in an API Call
#     sample 1/8  (log_prob=-5.1, tokens=177)
#     sample 2/8  (log_prob=-5.9, tokens=158)
#     sample 3/8  (log_prob=-7.1, tokens=151)
#     sample 4/8  (log_prob=-7.9, tokens=171)
#     sample 5/8  (log_prob=-4.1, tokens=158)
#     sample 6/8  (log_prob=-5.1, tokens=177)
#     sample 7/8  (log_prob=-5.1, tokens=177)
#     sample 8/8  (log_prob=-4.1, tokens=158)
#   PE=0.0335  DSE=0.6616  SE=0.0222  (2cl, 166tok)
#
# [67/110] Buffer Overflow in Local Command-Line Utilities
#     sample 1/8  (log_prob=-4.0, tokens=204)
#     sample 2/8  (log_prob=-4.3, tokens=204)
#     sample 3/8  (log_prob=-4.8, tokens=208)
#     sample 4/8  (log_prob=-7.7, tokens=159)
#     sample 5/8  (log_prob=-5.8, tokens=204)
#     sample 6/8  (log_prob=-4.8, tokens=208)
#     sample 7/8  (log_prob=-11.7, tokens=208)
#     sample 8/8  (log_prob=-4.8, tokens=208)
#   PE=0.0300  DSE=0.0000  SE=0.0142  (1cl, 200tok)
#
# [68/110] XML Ping of the Death
#     sample 1/8  (log_prob=-52.3, tokens=140)
#     sample 2/8  (log_prob=-3.5, tokens=101)
#     sample 3/8  (log_prob=-15.8, tokens=86)
#     sample 4/8  (log_prob=-5.3, tokens=101)
#     sample 5/8  (log_prob=-5.8, tokens=86)
#     sample 6/8  (log_prob=-32.2, tokens=184)
#     sample 7/8  (log_prob=-13.9, tokens=94)
#     sample 8/8  (log_prob=-7.6, tokens=105)
#   PE=0.1521  DSE=1.6675  SE=0.1466  (6cl, 112tok)
#
# [69/110] Exponential Data Expansion
#     sample 1/8  (log_prob=-20.4, tokens=129)
#     sample 2/8  (log_prob=-31.0, tokens=173)
#     sample 3/8  (log_prob=-12.3, tokens=162)
#     sample 4/8  (log_prob=-19.8, tokens=186)
#     sample 5/8  (log_prob=-17.3, tokens=173)
#     sample 6/8  (log_prob=-13.0, tokens=128)
#     sample 7/8  (log_prob=-17.7, tokens=124)
#     sample 8/8  (log_prob=-16.8, tokens=106)
#   PE=0.1255  DSE=1.9062  SE=0.1134  (7cl, 148tok)
#
# [70/110] Quadratic Data Expansion
#     sample 1/8  (log_prob=-20.5, tokens=153)
#     sample 2/8  (log_prob=-35.0, tokens=137)
#     sample 3/8  (log_prob=-26.0, tokens=185)
#     sample 4/8  (log_prob=-23.6, tokens=186)
#     sample 5/8  (log_prob=-17.0, tokens=132)
#     sample 6/8  (log_prob=-14.3, tokens=157)
#     sample 7/8  (log_prob=-18.4, tokens=131)
#     sample 8/8  (log_prob=-19.6, tokens=149)
#   PE=0.1418  DSE=1.9062  SE=0.1367  (7cl, 154tok)
#   [checkpoint saved]
#
# [71/110] Data Serialization External Entities Blowup
#     sample 1/8  (log_prob=-23.6, tokens=264)
#     sample 2/8  (log_prob=-33.2, tokens=230)
#     sample 3/8  (log_prob=-12.5, tokens=119)
#     sample 4/8  (log_prob=-12.4, tokens=151)
#     sample 5/8  (log_prob=-14.0, tokens=129)
#     sample 6/8  (log_prob=-15.0, tokens=153)
#     sample 7/8  (log_prob=-12.6, tokens=152)
#     sample 8/8  (log_prob=-9.1, tokens=154)
#   PE=0.0979  DSE=0.3768  SE=0.0561  (2cl, 169tok)
#
# [72/110] Serialized Data Parameter Blowup
#     sample 1/8  (log_prob=-4.2, tokens=67)
#     sample 2/8  (log_prob=-13.7, tokens=49)
#     sample 3/8  (log_prob=-6.1, tokens=54)
#     sample 4/8  (log_prob=-3.7, tokens=66)
#     sample 5/8  (log_prob=-4.2, tokens=67)
#     sample 6/8  (log_prob=-6.2, tokens=66)
#     sample 7/8  (log_prob=-4.2, tokens=67)
#     sample 8/8  (log_prob=-7.4, tokens=60)
#   PE=0.1004  DSE=0.3768  SE=0.0497  (2cl, 62tok)
#
# [73/110] Using Meta-characters in E-mail Headers to Inject Malicious Payloads
#     sample 1/8  (log_prob=-5.9, tokens=94)
#     sample 2/8  (log_prob=-5.2, tokens=109)
#     sample 3/8  (log_prob=-4.0, tokens=112)
#     sample 4/8  (log_prob=-4.8, tokens=113)
#     sample 5/8  (log_prob=-2.6, tokens=113)
#     sample 6/8  (log_prob=-4.0, tokens=112)
#     sample 7/8  (log_prob=-11.0, tokens=90)
#     sample 8/8  (log_prob=-4.2, tokens=118)
#   PE=0.0483  DSE=0.3768  SE=0.0284  (2cl, 108tok)
#
# [74/110] String Format Overflow in syslog()
#     sample 1/8  (log_prob=-21.1, tokens=114)
#     sample 2/8  (log_prob=-23.1, tokens=88)
#     sample 3/8  (log_prob=-13.3, tokens=95)
#     sample 4/8  (log_prob=-22.8, tokens=116)
#     sample 5/8  (log_prob=-28.9, tokens=133)
#     sample 6/8  (log_prob=-25.9, tokens=88)
#     sample 7/8  (log_prob=-24.6, tokens=134)
#     sample 8/8  (log_prob=-20.8, tokens=110)
#   PE=0.2057  DSE=1.4942  SE=0.1883  (5cl, 110tok)
#
# [75/110] HTTP Parameter Pollution (HPP)
#     sample 1/8  (log_prob=-13.2, tokens=126)
#     sample 2/8  (log_prob=-11.1, tokens=125)
#     sample 3/8  (log_prob=-6.8, tokens=133)
#     sample 4/8  (log_prob=-10.3, tokens=109)
#     sample 5/8  (log_prob=-7.5, tokens=101)
#     sample 6/8  (log_prob=-8.5, tokens=124)
#     sample 7/8  (log_prob=-3.2, tokens=129)
#     sample 8/8  (log_prob=-5.3, tokens=108)
#   PE=0.0688  DSE=0.9003  SE=0.0470  (3cl, 119tok)
#
# [76/110] Flash Parameter Injection
#     sample 1/8  (log_prob=-56.6, tokens=157)
#     sample 2/8  (log_prob=-35.5, tokens=159)
#     sample 3/8  (log_prob=-21.9, tokens=82)
#     sample 4/8  (log_prob=-34.1, tokens=137)
#     sample 5/8  (log_prob=-41.5, tokens=149)
#     sample 6/8  (log_prob=-29.9, tokens=135)
#     sample 7/8  (log_prob=-20.7, tokens=98)
#     sample 8/8  (log_prob=-53.1, tokens=131)
#   PE=0.2799  DSE=2.0794  SE=0.2799  (8cl, 131tok)
#
# [77/110] Cross-Site Flashing
#     sample 1/8  (log_prob=-7.2, tokens=85)
#     sample 2/8  (log_prob=-6.9, tokens=81)
#     sample 3/8  (log_prob=-9.9, tokens=88)
#     sample 4/8  (log_prob=-3.7, tokens=88)
#     sample 5/8  (log_prob=-7.2, tokens=85)
#     sample 6/8  (log_prob=-7.2, tokens=85)
#     sample 7/8  (log_prob=-5.3, tokens=84)
#     sample 8/8  (log_prob=-4.0, tokens=84)
#   PE=0.0757  DSE=0.0000  SE=0.0351  (1cl, 85tok)
#
# [78/110] Checksum Spoofing
#     sample 1/8  (log_prob=-39.9, tokens=171)
#     sample 2/8  (log_prob=-46.3, tokens=153)
#     sample 3/8  (log_prob=-63.1, tokens=250)
#     sample 4/8  (log_prob=-43.9, tokens=163)
#     sample 5/8  (log_prob=-43.7, tokens=221)
#     sample 6/8  (log_prob=-36.0, tokens=142)
#     sample 7/8  (log_prob=-40.9, tokens=168)
#     sample 8/8  (log_prob=-33.5, tokens=168)
#   PE=0.2417  DSE=1.9062  SE=0.2328  (7cl, 180tok)
#
# [79/110] Spoofing of UDDI/ebXML Messages
#     sample 1/8  (log_prob=-18.1, tokens=81)
#     sample 2/8  (log_prob=-24.6, tokens=86)
#     sample 3/8  (log_prob=-27.2, tokens=92)
#     sample 4/8  (log_prob=-76.0, tokens=148)
#     sample 5/8  (log_prob=-27.1, tokens=91)
#     sample 6/8  (log_prob=-24.6, tokens=110)
#     sample 7/8  (log_prob=-50.8, tokens=154)
#     sample 8/8  (log_prob=-67.4, tokens=161)
#   PE=0.3421  DSE=2.0794  SE=0.3421  (8cl, 115tok)
#
# [80/110] DNS Rebinding
#     sample 1/8  (log_prob=-6.2, tokens=96)
#     sample 2/8  (log_prob=-5.8, tokens=95)
#     sample 3/8  (log_prob=-23.7, tokens=79)
#     sample 4/8  (log_prob=-4.0, tokens=90)
#     sample 5/8  (log_prob=-6.1, tokens=90)
#     sample 6/8  (log_prob=-6.1, tokens=90)
#     sample 7/8  (log_prob=-7.5, tokens=89)
#     sample 8/8  (log_prob=-8.3, tokens=123)
#   PE=0.0900  DSE=0.9003  SE=0.0502  (3cl, 94tok)
#   [checkpoint saved]
#
# [81/110] DNS Spoofing
#     sample 1/8  (log_prob=-5.5, tokens=141)
#     sample 2/8  (log_prob=-9.1, tokens=137)
#     sample 3/8  (log_prob=-10.6, tokens=141)
#     sample 4/8  (log_prob=-11.1, tokens=141)
#     sample 5/8  (log_prob=-7.1, tokens=130)
#     sample 6/8  (log_prob=-5.5, tokens=141)
#     sample 7/8  (log_prob=-22.3, tokens=137)
#     sample 8/8  (log_prob=-4.5, tokens=102)
#   PE=0.0708  DSE=1.2130  SE=0.0557  (4cl, 134tok)
#
# [82/110] Token Impersonation
#     sample 1/8  (log_prob=-40.4, tokens=153)
#     sample 2/8  (log_prob=-49.5, tokens=203)
#     sample 3/8  (log_prob=-105.0, tokens=275)
#     sample 4/8  (log_prob=-112.4, tokens=212)
#     sample 5/8  (log_prob=-55.4, tokens=212)
#     sample 6/8  (log_prob=-44.8, tokens=164)
#     sample 7/8  (log_prob=-51.9, tokens=160)
#     sample 8/8  (log_prob=-62.8, tokens=145)
#   PE=0.3426  DSE=1.9062  SE=0.3397  (7cl, 190tok)
#
# [83/110] Creating a Rogue Certification Authority Certificate
#     sample 1/8  (log_prob=-36.0, tokens=140)
#     sample 2/8  (log_prob=-76.8, tokens=153)
#     sample 3/8  (log_prob=-34.3, tokens=145)
#     sample 4/8  (log_prob=-87.3, tokens=178)
#     sample 5/8  (log_prob=-60.1, tokens=155)
#     sample 6/8  (log_prob=-54.1, tokens=162)
#     sample 7/8  (log_prob=-24.4, tokens=71)
#     sample 8/8  (log_prob=-54.8, tokens=113)
#   PE=0.3830  DSE=1.9062  SE=0.3586  (7cl, 140tok)
#
# [84/110] Signature Spoofing by Key Theft
#     sample 1/8  (log_prob=-5.6, tokens=119)
#     sample 2/8  (log_prob=-10.2, tokens=144)
#     sample 3/8  (log_prob=-5.6, tokens=119)
#     sample 4/8  (log_prob=-5.6, tokens=119)
#     sample 5/8  (log_prob=-3.5, tokens=119)
#     sample 6/8  (log_prob=-13.3, tokens=111)
#     sample 7/8  (log_prob=-7.9, tokens=119)
#     sample 8/8  (log_prob=-15.1, tokens=146)
#   PE=0.0669  DSE=1.3863  SE=0.0594  (5cl, 124tok)
#
# [85/110] Signature Spoofing by Improper Validation
#     sample 1/8  (log_prob=-24.2, tokens=106)
#     sample 2/8  (log_prob=-65.0, tokens=184)
#     sample 3/8  (log_prob=-37.3, tokens=133)
#     sample 4/8  (log_prob=-30.8, tokens=92)
#     sample 5/8  (log_prob=-34.7, tokens=126)
#     sample 6/8  (log_prob=-48.8, tokens=144)
#     sample 7/8  (log_prob=-17.7, tokens=63)
#     sample 8/8  (log_prob=-34.0, tokens=125)
#   PE=0.3005  DSE=1.7329  SE=0.2856  (6cl, 122tok)
#
# [86/110] Signature Spoofing by Misrepresentation
#     sample 1/8  (log_prob=-38.6, tokens=130)
#     sample 2/8  (log_prob=-30.8, tokens=167)
#     sample 3/8  (log_prob=-29.3, tokens=143)
#     sample 4/8  (log_prob=-18.5, tokens=149)
#     sample 5/8  (log_prob=-23.3, tokens=131)
#     sample 6/8  (log_prob=-18.5, tokens=112)
#     sample 7/8  (log_prob=-46.2, tokens=123)
#     sample 8/8  (log_prob=-28.6, tokens=124)
#   PE=0.2167  DSE=2.0794  SE=0.2167  (8cl, 135tok)
#
# [87/110] Signature Spoofing by Mixing Signed and Unsigned Content
#     sample 1/8  (log_prob=-8.7, tokens=69)
#     sample 2/8  (log_prob=-26.0, tokens=94)
#     sample 3/8  (log_prob=-11.9, tokens=67)
#     sample 4/8  (log_prob=-15.9, tokens=85)
#     sample 5/8  (log_prob=-43.5, tokens=122)
#     sample 6/8  (log_prob=-12.9, tokens=62)
#     sample 7/8  (log_prob=-5.5, tokens=62)
#     sample 8/8  (log_prob=-7.8, tokens=62)
#   PE=0.2120  DSE=1.0735  SE=0.1800  (4cl, 78tok)
#
# [88/110] Malicious Root Certificate
#     sample 1/8  (log_prob=-66.5, tokens=187)
#     sample 2/8  (log_prob=-41.8, tokens=230)
#     sample 3/8  (log_prob=-94.8, tokens=285)
#     sample 4/8  (log_prob=-53.8, tokens=238)
#     sample 5/8  (log_prob=-53.2, tokens=133)
#     sample 6/8  (log_prob=-90.4, tokens=155)
#     sample 7/8  (log_prob=-43.2, tokens=199)
#     sample 8/8  (log_prob=-63.0, tokens=212)
#   PE=0.3092  DSE=1.9062  SE=0.2843  (7cl, 205tok)
#
# [89/110] Signature Spoofing by Key Recreation
#     sample 1/8  (log_prob=-45.0, tokens=179)
#     sample 2/8  (log_prob=-62.5, tokens=135)
#     sample 3/8  (log_prob=-95.1, tokens=198)
#     sample 4/8  (log_prob=-27.4, tokens=110)
#     sample 5/8  (log_prob=-43.3, tokens=131)
#     sample 6/8  (log_prob=-43.8, tokens=110)
#     sample 7/8  (log_prob=-63.6, tokens=174)
#     sample 8/8  (log_prob=-61.7, tokens=152)
#   PE=0.3720  DSE=2.0794  SE=0.3720  (8cl, 149tok)
#
# [90/110] Relative Path Traversal
#     sample 1/8  (log_prob=-8.5, tokens=219)
#     sample 2/8  (log_prob=-28.1, tokens=226)
#     sample 3/8  (log_prob=-17.4, tokens=250)
#     sample 4/8  (log_prob=-12.3, tokens=208)
#     sample 5/8  (log_prob=-19.0, tokens=225)
#     sample 6/8  (log_prob=-4.9, tokens=223)
#     sample 7/8  (log_prob=-12.7, tokens=213)
#     sample 8/8  (log_prob=-7.4, tokens=219)
#   PE=0.0620  DSE=1.3863  SE=0.0504  (5cl, 223tok)
#   [checkpoint saved]
#
# [91/110] Absolute Path Traversal
#     sample 1/8  (log_prob=-4.8, tokens=490)
#     sample 2/8  (log_prob=-18.9, tokens=463)
#     sample 3/8  (log_prob=-5.2, tokens=486)
#     sample 4/8  (log_prob=-21.1, tokens=251)
#     sample 5/8  (log_prob=-13.2, tokens=294)
#     sample 6/8  (log_prob=-20.1, tokens=459)
#     sample 7/8  (log_prob=-5.9, tokens=430)
#     sample 8/8  (log_prob=-4.5, tokens=402)
#   PE=0.0286  DSE=0.7356  SE=0.0170  (3cl, 409tok)
#
# [92/110] Manipulating Web Input to File System Calls
#     sample 1/8  (log_prob=-4.2, tokens=190)
#     sample 2/8  (log_prob=-20.0, tokens=181)
#     sample 3/8  (log_prob=-23.6, tokens=172)
#     sample 4/8  (log_prob=-26.3, tokens=178)
#     sample 5/8  (log_prob=-11.7, tokens=204)
#     sample 6/8  (log_prob=-16.5, tokens=112)
#     sample 7/8  (log_prob=-20.1, tokens=172)
#     sample 8/8  (log_prob=-20.6, tokens=157)
#   PE=0.1047  DSE=1.2555  SE=0.0789  (4cl, 171tok)
#
# [93/110] Forced Integer Overflow
#     sample 1/8  (log_prob=-8.1, tokens=147)
#     sample 2/8  (log_prob=-1.9, tokens=124)
#     sample 3/8  (log_prob=-9.2, tokens=147)
#     sample 4/8  (log_prob=-7.2, tokens=124)
#     sample 5/8  (log_prob=-8.1, tokens=147)
#     sample 6/8  (log_prob=-8.1, tokens=147)
#     sample 7/8  (log_prob=-8.7, tokens=123)
#     sample 8/8  (log_prob=-13.3, tokens=97)
#   PE=0.0612  DSE=0.6931  SE=0.0333  (2cl, 132tok)
#
# [94/110] Double Encoding
#     sample 1/8  (log_prob=-39.2, tokens=270)
#     sample 2/8  (log_prob=-40.2, tokens=401)
#     sample 3/8  (log_prob=-42.7, tokens=269)
#     sample 4/8  (log_prob=-40.6, tokens=296)
#     sample 5/8  (log_prob=-24.2, tokens=288)
#     sample 6/8  (log_prob=-33.7, tokens=248)
#     sample 7/8  (log_prob=-37.9, tokens=373)
#     sample 8/8  (log_prob=-46.7, tokens=294)
#   PE=0.1251  DSE=0.3768  SE=0.0850  (2cl, 305tok)
#
# [95/110] Using Leading 'Ghost' Character Sequences to Bypass Input Filters
#     sample 1/8  (log_prob=-15.7, tokens=105)
#     sample 2/8  (log_prob=-23.6, tokens=138)
#     sample 3/8  (log_prob=-7.3, tokens=91)
#     sample 4/8  (log_prob=-40.6, tokens=151)
#     sample 5/8  (log_prob=-9.4, tokens=94)
#     sample 6/8  (log_prob=-45.7, tokens=178)
#     sample 7/8  (log_prob=-24.4, tokens=174)
#     sample 8/8  (log_prob=-49.0, tokens=151)
#   PE=0.1995  DSE=1.9062  SE=0.1973  (7cl, 135tok)
#
# [96/110] Using Alternative IP Address Encodings
#     sample 1/8  (log_prob=-6.9, tokens=132)
#     sample 2/8  (log_prob=-10.0, tokens=136)
#     sample 3/8  (log_prob=-10.6, tokens=91)
#     sample 4/8  (log_prob=-6.4, tokens=135)
#     sample 5/8  (log_prob=-28.3, tokens=100)
#     sample 6/8  (log_prob=-3.3, tokens=132)
#     sample 7/8  (log_prob=-13.1, tokens=155)
#     sample 8/8  (log_prob=-6.4, tokens=135)
#   PE=0.0834  DSE=0.7356  SE=0.0418  (3cl, 127tok)
#
# [97/110] Exploiting Multiple Input Interpretation Layers
#     sample 1/8  (log_prob=-14.0, tokens=125)
#     sample 2/8  (log_prob=-19.4, tokens=128)
#     sample 3/8  (log_prob=-15.1, tokens=141)
#     sample 4/8  (log_prob=-17.8, tokens=135)
#     sample 5/8  (log_prob=-15.8, tokens=123)
#     sample 6/8  (log_prob=-22.7, tokens=101)
#     sample 7/8  (log_prob=-28.0, tokens=79)
#     sample 8/8  (log_prob=-18.8, tokens=134)
#   PE=0.1571  DSE=1.7329  SE=0.1465  (6cl, 121tok)
#
# [98/110] Embedding NULL Bytes
#     sample 1/8  (log_prob=-13.2, tokens=77)
#     sample 2/8  (log_prob=-38.9, tokens=172)
#     sample 3/8  (log_prob=-27.0, tokens=111)
#     sample 4/8  (log_prob=-48.8, tokens=162)
#     sample 5/8  (log_prob=-23.1, tokens=124)
#     sample 6/8  (log_prob=-106.2, tokens=244)
#     sample 7/8  (log_prob=-43.7, tokens=159)
#     sample 8/8  (log_prob=-12.5, tokens=78)
#   PE=0.2782  DSE=1.9062  SE=0.2769  (7cl, 141tok)
#
# [99/110] Postfix, Null Terminate, and Backslash
#     sample 1/8  (log_prob=-24.1, tokens=117)
#     sample 2/8  (log_prob=-25.9, tokens=113)
#     sample 3/8  (log_prob=-18.0, tokens=114)
#     sample 4/8  (log_prob=-17.3, tokens=102)
#     sample 5/8  (log_prob=-22.0, tokens=87)
#     sample 6/8  (log_prob=-21.4, tokens=100)
#     sample 7/8  (log_prob=-10.7, tokens=126)
#     sample 8/8  (log_prob=-47.2, tokens=176)
#   PE=0.1997  DSE=1.9062  SE=0.1926  (7cl, 117tok)
#
# [100/110] Using Slashes and URL Encoding Combined to Bypass Validation Logic
#     sample 1/8  (log_prob=-57.2, tokens=269)
#     sample 2/8  (log_prob=-32.5, tokens=315)
#     sample 3/8  (log_prob=-23.6, tokens=331)
#     sample 4/8  (log_prob=-9.7, tokens=341)
#     sample 5/8  (log_prob=-16.3, tokens=434)
#     sample 6/8  (log_prob=-45.0, tokens=329)
#     sample 7/8  (log_prob=-12.8, tokens=376)
#     sample 8/8  (log_prob=-36.9, tokens=213)
#   PE=0.0897  DSE=1.2130  SE=0.0643  (4cl, 326tok)
#   [checkpoint saved]
#
# [101/110] Using Unicode Encoding to Bypass Validation Logic
#     sample 1/8  (log_prob=-6.2, tokens=115)
#     sample 2/8  (log_prob=-7.2, tokens=115)
#     sample 3/8  (log_prob=-6.1, tokens=111)
#     sample 4/8  (log_prob=-6.1, tokens=111)
#     sample 5/8  (log_prob=-6.1, tokens=111)
#     sample 6/8  (log_prob=-4.7, tokens=102)
#     sample 7/8  (log_prob=-6.3, tokens=102)
#     sample 8/8  (log_prob=-7.5, tokens=133)
#   PE=0.0560  DSE=0.3768  SE=0.0388  (2cl, 112tok)
#
# [102/110] URL Encoding
#     sample 1/8  (log_prob=-8.4, tokens=375)
#     sample 2/8  (log_prob=-26.6, tokens=224)
#     sample 3/8  (log_prob=-28.5, tokens=215)
#     sample 4/8  (log_prob=-22.0, tokens=219)
#     sample 5/8  (log_prob=-31.9, tokens=206)
#     sample 6/8  (log_prob=-28.4, tokens=253)
#     sample 7/8  (log_prob=-44.8, tokens=262)
#     sample 8/8  (log_prob=-27.2, tokens=232)
#   PE=0.1097  DSE=1.6675  SE=0.1014  (6cl, 248tok)
#
# [103/110] Using Escaped Slashes in Alternate Encoding
#     sample 1/8  (log_prob=-10.9, tokens=272)
#     sample 2/8  (log_prob=-6.7, tokens=339)
#     sample 3/8  (log_prob=-6.4, tokens=310)
#     sample 4/8  (log_prob=-5.0, tokens=326)
#     sample 5/8  (log_prob=-7.0, tokens=270)
#     sample 6/8  (log_prob=-5.0, tokens=330)
#     sample 7/8  (log_prob=-2.8, tokens=330)
#     sample 8/8  (log_prob=-7.0, tokens=313)
#   PE=0.0204  DSE=0.0000  SE=0.0082  (1cl, 311tok)
#
# [104/110] Using Slashes in Alternate Encoding
#     sample 1/8  (log_prob=-13.5, tokens=191)
#     sample 2/8  (log_prob=-25.8, tokens=211)
#     sample 3/8  (log_prob=-20.8, tokens=186)
#     sample 4/8  (log_prob=-36.6, tokens=177)
#     sample 5/8  (log_prob=-34.1, tokens=208)
#     sample 6/8  (log_prob=-44.3, tokens=176)
#     sample 7/8  (log_prob=-60.3, tokens=248)
#     sample 8/8  (log_prob=-18.6, tokens=178)
#   PE=0.1613  DSE=1.9062  SE=0.1499  (7cl, 197tok)
#
# [105/110] Using UTF-
#     sample 1/8  (log_prob=-54.3, tokens=353)
#     sample 2/8  (log_prob=-44.9, tokens=146)
#     sample 3/8  (log_prob=-47.6, tokens=451)
#     sample 4/8  (log_prob=-33.6, tokens=279)
#     sample 5/8  (log_prob=-47.7, tokens=211)
#     sample 6/8  (log_prob=-50.0, tokens=333)
#     sample 7/8  (log_prob=-35.4, tokens=263)
#     sample 8/8  (log_prob=-36.1, tokens=154)
#   PE=0.1596  DSE=1.4942  SE=0.1391  (5cl, 274tok)
#
# [106/110] Symlink Attack
#     sample 1/8  (log_prob=-14.8, tokens=85)
#     sample 2/8  (log_prob=-14.1, tokens=118)
#     sample 3/8  (log_prob=-5.8, tokens=89)
#     sample 4/8  (log_prob=-3.8, tokens=89)
#     sample 5/8  (log_prob=-10.8, tokens=120)
#     sample 6/8  (log_prob=-16.6, tokens=115)
#     sample 7/8  (log_prob=-9.0, tokens=104)
#     sample 8/8  (log_prob=-13.0, tokens=82)
#   PE=0.1097  DSE=1.3863  SE=0.0842  (5cl, 100tok)
#
# [107/110] Leveraging/Manipulating Configuration File Search Paths
#     sample 1/8  (log_prob=-5.1, tokens=111)
#     sample 2/8  (log_prob=-17.5, tokens=85)
#     sample 3/8  (log_prob=-10.9, tokens=94)
#     sample 4/8  (log_prob=-10.4, tokens=94)
#     sample 5/8  (log_prob=-9.7, tokens=108)
#     sample 6/8  (log_prob=-3.9, tokens=115)
#     sample 7/8  (log_prob=-5.1, tokens=105)
#     sample 8/8  (log_prob=-15.7, tokens=113)
#   PE=0.0951  DSE=0.9003  SE=0.0558  (3cl, 103tok)
#
# [108/110] Search Order Hijacking
#     sample 1/8  (log_prob=-4.7, tokens=86)
#     sample 2/8  (log_prob=-4.8, tokens=69)
#     sample 3/8  (log_prob=-21.9, tokens=83)
#     sample 4/8  (log_prob=-4.6, tokens=82)
#     sample 5/8  (log_prob=-2.7, tokens=86)
#     sample 6/8  (log_prob=-10.6, tokens=59)
#     sample 7/8  (log_prob=-6.3, tokens=54)
#     sample 8/8  (log_prob=-2.7, tokens=86)
#   PE=0.0963  DSE=1.3863  SE=0.0842  (5cl, 76tok)
#
# [109/110] DLL Side-Loading
#     sample 1/8  (log_prob=-4.5, tokens=160)
#     sample 2/8  (log_prob=-2.7, tokens=160)
#     sample 3/8  (log_prob=-8.4, tokens=155)
#     sample 4/8  (log_prob=-4.5, tokens=156)
#     sample 5/8  (log_prob=-6.4, tokens=146)
#     sample 6/8  (log_prob=-3.4, tokens=160)
#     sample 7/8  (log_prob=-4.5, tokens=156)
#     sample 8/8  (log_prob=-2.8, tokens=159)
#   PE=0.0297  DSE=0.0000  SE=0.0103  (1cl, 156tok)
#
# [110/110] Evil Twin Wi-Fi Attack
#     sample 1/8  (log_prob=-54.0, tokens=139)
#     sample 2/8  (log_prob=-46.5, tokens=184)
#     sample 3/8  (log_prob=-16.4, tokens=95)
#     sample 4/8  (log_prob=-57.4, tokens=182)
#     sample 5/8  (log_prob=-32.3, tokens=145)
#     sample 6/8  (log_prob=-27.6, tokens=151)
#     sample 7/8  (log_prob=-56.6, tokens=169)
#     sample 8/8  (log_prob=-64.3, tokens=174)
#   PE=0.2866  DSE=2.0794  SE=0.2866  (8cl, 155tok)
#   [checkpoint saved]
#
# Done. 110 attacks processed.

# %% [markdown]
# ---
# ## 10. Illustrative walkthrough — one query end-to-end
#
# Visual sanity check: trace the full pipeline for a single attack.
#
# **Pipeline:** Prompt → M responses (with log-probs and token counts) → JSON→NL conversion → NLI clustering → three entropy metrics.
#
# The table shows raw and length-normalized values side by side, plus the gap $PE - SE$ which measures how much phrasing variation was removed by semantic clustering.

# %%
EX_IDX = 2  # ← change to inspect a different attack

ex = df.iloc[EX_IDX]
print(f"━━━ ATTACK: {ex.attack} ━━━\n")
print(f"{'Metric':<35} {'Raw':>12} {'Normalized':>12}")
print(f"{'─'*60}")
print(f"{'Predictive Entropy (PE)':<35} {ex.pe:>12.4f} {ex.pe_norm:>12.4f}")
print(f"{'Semantic Entropy (SE)':<35} {ex.se:>12.4f} {ex.se_norm:>12.4f}")
print(f"{'Discrete Semantic Entropy (DSE)':<35} {ex.dse:>12.4f} {'(n/a)':>12}")
print(f"{'Gap PE-SE (phrasing noise)':<35} {ex.pe - ex.se:>12.4f} {ex.pe_norm - ex.se_norm:>12.4f}")
print(f"{'Average tokens':<35} {ex.avg_tokens:>12.0f}")
print(f"{'NLI clusters':<35} {ex.clusters_nli:>12}")
print()
print("PROMPT (first 300 chars):")
print(build_prompt(ex.attack, attacks[EX_IDX]["mitigations"])[:300], "...\n")

# ── Show all M responses ──
for i, (raw, nl, lp, nt) in enumerate(zip(ex.responses, ex.responses_nl, ex.log_probs, ex.n_tokens)):
    excerpt = raw.replace("\n", " ")[:300]
    print(f"┌─ R{i+1}  [log-prob = {lp:.1f}, tokens = {nt}, per-token = {lp/max(nt,1):.3f}]")
    print(f"│  RAW: {excerpt}{'...' if len(raw) > 300 else ''}")
    print(f"│  NL:  {nl[:300]}{'...' if len(nl) > 300 else ''}")
    print(f"└{'─'*60}\n")
# Out:
# ━━━ ATTACK: Session Sidejacking ━━━
#
# Metric                                       Raw   Normalized
# ────────────────────────────────────────────────────────────
# Predictive Entropy (PE)                  11.8672       0.1252
# Semantic Entropy (SE)                    10.8573       0.1146
# Discrete Semantic Entropy (DSE)           1.9062        (n/a)
# Gap PE-SE (phrasing noise)                1.0099       0.0107
# Average tokens                                95
# NLI clusters                                   7
#
# PROMPT (first 300 chars):
# return a list of mitigation names and their priority, in json format, for the attack 'Session Sidejacking', including and expanding this mitigation list according to CAPEC ['Make sure that HTTPS is used to communicate with the target system. Alternatively, use VPN if possible. It is important to ens ...
#
# ┌─ R1  [log-prob = -12.4, tokens = 87, per-token = -0.142]
# │  RAW: ``` {   "mitigations": [     {       "name": "Use HTTPS or VPN to encrypt communication",       "priority": 1     },     {       "name": "Modify session token and protect it with cryptography",       "priority": 2     },     {       "name": "Implement request sequencing for replay attack detection",...
# │  NL:  1. Use HTTPS or VPN to encrypt communication, 2. Modify session token and protect it with cryptography, 3. Implement request sequencing for replay attack detection
# └────────────────────────────────────────────────────────────
#
# ┌─ R2  [log-prob = -7.6, tokens = 91, per-token = -0.083]
# │  RAW: ```json {     "mitigations": [         {             "name": "Use HTTPS or VPN to encrypt communication",             "priority": 1         },         {             "name": "Modify session token with each transmission and protect it with cryptography",             "priority": 2         },         { ...
# │  NL:  1. Use HTTPS or VPN to encrypt communication, 2. Modify session token with each transmission and protect it with cryptography, 3. Implement request sequencing to detect replay attacks
# └────────────────────────────────────────────────────────────
#
# ┌─ R3  [log-prob = -9.4, tokens = 97, per-token = -0.097]
# │  RAW: ```json {   "mitigations": [     {       "name": "Use HTTPS to communicate with the target system or use a VPN",       "priority": 1     },     {       "name": "Modify the session token with each transmission and protect it with cryptography",       "priority": 2     },     {       "name": "Add requ...
# │  NL:  1. Use HTTPS to communicate with the target system or use a VPN, 2. Modify the session token with each transmission and protect it with cryptography, 3. Add request sequencing to detect replay attacks
# └────────────────────────────────────────────────────────────
#
# ┌─ R4  [log-prob = -10.9, tokens = 113, per-token = -0.096]
# │  RAW: ```json {     "mitigations": [         {             "name": "Use HTTPS to communicate with the target system",             "priority": 1         },         {             "name": "Modify the session token with each transmission and protect it with cryptography",             "priority": 2         }, ...
# │  NL:  1. Use HTTPS to communicate with the target system, 2. Modify the session token with each transmission and protect it with cryptography, 3. Request sequencing to detect replay attacks, 4. Use VPN if possible
# └────────────────────────────────────────────────────────────
#
# ┌─ R5  [log-prob = -7.6, tokens = 91, per-token = -0.083]
# │  RAW: ```json {     "mitigations": [         {             "name": "Use HTTPS or VPN to encrypt communication",             "priority": 1         },         {             "name": "Modify session token with each transmission and protect it with cryptography",             "priority": 2         },         { ...
# │  NL:  1. Use HTTPS or VPN to encrypt communication, 2. Modify session token with each transmission and protect it with cryptography, 3. Implement request sequencing to detect replay attacks
# └────────────────────────────────────────────────────────────
#
# ┌─ R6  [log-prob = -13.1, tokens = 88, per-token = -0.149]
# │  RAW: ```json {     "mitigations": [         {             "name": "Use HTTPS or VPN to encrypt communication",             "priority": 1         },         {             "name": "Modify session token and protect it with cryptography",             "priority": 2         },         {             "name": "Im...
# │  NL:  1. Use HTTPS or VPN to encrypt communication, 2. Modify session token and protect it with cryptography, 3. Implement request sequencing for replay attack detection
# └────────────────────────────────────────────────────────────
#
# ┌─ R7  [log-prob = -20.4, tokens = 80, per-token = -0.255]
# │  RAW: ``` [   {     "name": "Implement Secure Communication Protocols (HTTPS/VPN)",     "priority": 1   },   {     "name": "Modify Session Token and Protect with Cryptography",     "priority": 2   },   {     "name": "Request Sequencing to Detect Replay Attacks",     "priority": 3   } ] ```
# │  NL:  1. Implement Secure Communication Protocols (HTTPS/VPN), 2. Modify Session Token and Protect with Cryptography, 3. Request Sequencing to Detect Replay Attacks
# └────────────────────────────────────────────────────────────
#
# ┌─ R8  [log-prob = -13.5, tokens = 111, per-token = -0.122]
# │  RAW: ```json {     "mitigations": [         {             "name": "Implement HTTPS to encrypt communication",             "priority": 1         },         {             "name": "Use VPN for secure communication",             "priority": 2         },         {             "name": "Modify session token wit...
# │  NL:  1. Implement HTTPS to encrypt communication, 2. Use VPN for secure communication, 3. Modify session token with each transmission and protect it with cryptography, 4. Implement request sequencing to detect replay attacks
# └────────────────────────────────────────────────────────────

# %%
# ── Cosine similarity heatmap ────────────────────────────────
emb_ex = embedder.encode(ex.responses_nl)
sim_ex = cosine_similarity(emb_ex)
rlabels = [f"R{i+1}" for i in range(M)]

fig, ax = plt.subplots(figsize=(5.5, 4.5))
sns.heatmap(sim_ex, annot=True, fmt=".2f", cmap="YlOrRd",
            xticklabels=rlabels, yticklabels=rlabels, vmin=0.5, vmax=1.0, linewidths=0.5, ax=ax)
cl_cosine_ex = cluster_by_cosine(ex.responses_nl)
for cl in cl_cosine_ex:
    if len(cl) > 1:
        mn, mx = min(cl), max(cl)
        ax.add_patch(plt.Rectangle((mn, mn), mx - mn + 1, mx - mn + 1,
                                    fill=False, edgecolor="blue", linewidth=2, linestyle="--"))
ax.set_title(f"Cosine Similarity — {ex.attack}\n(blue boxes = clusters, τ={COSINE_THRESHOLD})")
plt.tight_layout()
plt.show()
print(f"Cosine clusters: {[['R'+str(j+1) for j in c] for c in cl_cosine_ex]}")

# ── NLI pairwise matrix ─────────────────────────────────────
cl_nli_ex = cluster_by_nli(ex.responses_nl)
n_ex = len(ex.responses_nl)
nli_labels = pd.DataFrame("", index=rlabels, columns=rlabels)
for i in range(n_ex):
    for j in range(n_ex):
        if i == j:
            nli_labels.iloc[i, j] = "SELF"
        else:
            r = nli(f"{ex.responses_nl[i]}</s></s>{ex.responses_nl[j]}", truncation=True)[0]
            nli_labels.iloc[i, j] = r["label"][:3]

print(f"\nNLI pairwise matrix (ENT/CON/NEU — same cluster iff both directions ENT):")
print(nli_labels.to_string())
print(f"NLI clusters: {[['R'+str(j+1) for j in c] for c in cl_nli_ex]}")
# Out:
# Cosine clusters: [['R1', 'R2', 'R3', 'R4', 'R5', 'R6', 'R7', 'R8']]
#
# NLI pairwise matrix (ENT/CON/NEU — same cluster iff both directions ENT):
#       R1    R2    R3    R4    R5    R6    R7    R8
# R1  SELF   NEU   NEU   NEU   NEU   NEU   ENT   NEU
# R2   NEU  SELF   NEU   NEU   NEU   NEU   ENT   NEU
# R3   ENT   ENT  SELF   ENT   ENT   ENT   ENT   ENT
# R4   NEU   NEU   NEU  SELF   NEU   NEU   ENT   NEU
# R5   NEU   NEU   NEU   NEU  SELF   NEU   ENT   NEU
# R6   NEU   NEU   NEU   NEU   NEU  SELF   ENT   NEU
# R7   ENT   ENT   ENT   NEU   ENT   ENT  SELF   ENT
# R8   ENT   ENT   NEU   NEU   ENT   ENT   ENT  SELF
# NLI clusters: [['R1', 'R7'], ['R2'], ['R3'], ['R4'], ['R5'], ['R6'], ['R8']]

# %%
# ── Entropy breakdown ─────────────────────────────────────
lp = np.array(ex.log_probs)
pe = predictive_entropy(ex.log_probs)
se = semantic_entropy(cl_nli_ex, ex.log_probs)
dse = discrete_semantic_entropy(cl_nli_ex, M)

print("━━━ METRIC 1: PREDICTIVE ENTROPY ━━━")
print(f"  PE = -1/{M} × Σ log p(s_i|x)\n")
print(f"  {'Resp':<6} {'log p(s|x)':>12} {'tokens':>8} {'per-token':>10}")
print(f"  {'─'*38}")
for j, (lpi, nt) in enumerate(zip(ex.log_probs, ex.n_tokens)):
    print(f"  R{j+1:<5} {lpi:>12.2f} {nt:>8} {lpi/max(nt,1):>10.4f}")
print(f"\n  PE = -1/{M} × ({sum(ex.log_probs):.2f}) = {pe:.4f}")
print(f"  PE_norm = {pe:.4f} / {np.mean(ex.n_tokens):.0f} = {normalize_by_length(pe, ex.n_tokens):.4f}\n")

print("━━━ METRIC 2: DISCRETE SEMANTIC ENTROPY ━━━")
print(f"  DSE = -Σ_k (|C_k|/M) × log(|C_k|/M)\n")
for k, c in enumerate(cl_nli_ex):
    members = '+'.join([f'R{j+1}' for j in c])
    p_k = len(c) / M
    print(f"  C{k+1}: {members:<20} |C|/M = {p_k:.2f}")
print(f"\n  DSE = {dse:.4f}\n")

print("━━━ METRIC 3: SEMANTIC ENTROPY (MC, log-prob weighted) ━━━")
print(f"  SE = -Σ_k (|C_k|/M) × logsumexp(log-probs in C_k)\n")
for k, c in enumerate(cl_nli_ex):
    members = '+'.join([f'R{j+1}' for j in c])
    log_p_ck = logsumexp(lp[c])
    weight = len(c) / M
    print(f"  C{k+1}: {members:<20} weight={weight:.2f}  logsumexp={log_p_ck:.2f}  contrib={-weight*log_p_ck:.4f}")
print(f"\n  SE = {se:.4f}")
print(f"  SE_norm = {se:.4f} / {np.mean(ex.n_tokens):.0f} = {normalize_by_length(se, ex.n_tokens):.4f}\n")

print("━━━ SUMMARY ━━━")
print(f"  PE_norm  = {normalize_by_length(pe, ex.n_tokens):.6f}  (total uncertainty per token)")
print(f"  SE_norm  = {normalize_by_length(se, ex.n_tokens):.6f}  (semantic uncertainty per token)")
print(f"  DSE      = {dse:.6f}  (cluster disagreement, length-free)")
print(f"  Gap      = {normalize_by_length(pe - se, ex.n_tokens):.6f}  (phrasing noise per token)")
print(f"  SE <= PE: {'✓' if se <= pe + 1e-10 else '✗ BUG'}")
# Out:
# ━━━ METRIC 1: PREDICTIVE ENTROPY ━━━
#   PE = -1/8 × Σ log p(s_i|x)
#
#   Resp     log p(s|x)   tokens  per-token
#   ──────────────────────────────────────
#   R1           -12.36       87    -0.1420
#   R2            -7.57       91    -0.0832
#   R3            -9.43       97    -0.0973
#   R4           -10.90      113    -0.0965
#   R5            -7.57       91    -0.0832
#   R6           -13.13       88    -0.1492
#   R7           -20.43       80    -0.2554
#   R8           -13.53      111    -0.1219
#
#   PE = -1/8 × (-94.94) = 11.8672
#   PE_norm = 11.8672 / 95 = 0.1252
#
# ━━━ METRIC 2: DISCRETE SEMANTIC ENTROPY ━━━
#   DSE = -Σ_k (|C_k|/M) × log(|C_k|/M)
#
#   C1: R1+R7                |C|/M = 0.25
#   C2: R2                   |C|/M = 0.12
#   C3: R3                   |C|/M = 0.12
#   C4: R4                   |C|/M = 0.12
#   C5: R5                   |C|/M = 0.12
#   C6: R6                   |C|/M = 0.12
#   C7: R8                   |C|/M = 0.12
#
#   DSE = 1.9062
#
# ━━━ METRIC 3: SEMANTIC ENTROPY (MC, log-prob weighted) ━━━
#   SE = -Σ_k (|C_k|/M) × logsumexp(log-probs in C_k)
#
#   C1: R1+R7                weight=0.25  logsumexp=-12.36  contrib=3.0889
#   C2: R2                   weight=0.12  logsumexp=-7.57  contrib=0.9464
#   C3: R3                   weight=0.12  logsumexp=-9.43  contrib=1.1793
#   C4: R4                   weight=0.12  logsumexp=-10.90  contrib=1.3630
#   C5: R5                   weight=0.12  logsumexp=-7.57  contrib=0.9464
#   C6: R6                   weight=0.12  logsumexp=-13.13  contrib=1.6416
#   C7: R8                   weight=0.12  logsumexp=-13.53  contrib=1.6918
#
#   SE = 10.8573
#   SE_norm = 10.8573 / 95 = 0.1146
#
# ━━━ SUMMARY ━━━
#   PE_norm  = 0.125248  (total uncertainty per token)
#   SE_norm  = 0.114589  (semantic uncertainty per token)
#   DSE      = 1.906155  (cluster disagreement, length-free)
#   Gap      = 0.010658  (phrasing noise per token)
#   SE <= PE: ✓

# %% [markdown]
# ## 11. Results table
#
# All three comparable metrics for every attack. Color gradient: red = high uncertainty, green = low uncertainty.
#
# - **PE (norm):** per-token surprise. High = the model is unsure token-by-token.
# - **SE (norm):** per-token semantic uncertainty. High = the model gives different meanings, not just different words.
# - **Discrete SE:** cluster disagreement. 0 = all responses equivalent. $\log(5) \approx 1.61$ = all responses different.

# %%
df[["attack", "pe_norm", "se_norm", "dse", "clusters_nli", "avg_tokens"]].rename(columns={
    "pe_norm": "PE (norm)",
    "se_norm": "SE (norm)",
    "dse": "Discrete SE",
    "clusters_nli": "Clusters",
    "avg_tokens": "Avg Tok"
}).style.format({
    "PE (norm)": "{:.6f}",
    "SE (norm)": "{:.6f}",
    "Discrete SE": "{:.6f}",
    "Avg Tok": "{:.0f}"
}).background_gradient(
    subset=["PE (norm)", "SE (norm)", "Discrete SE"], cmap="RdYlGn_r"
)
# Out:
# <style type="text/css">
# #T_de0b1_row0_col1 {
#   background-color: #f16640;
#   color: #f1f1f1;
# }
# #T_de0b1_row0_col2, #T_de0b1_row26_col1 {
#   background-color: #ef633f;
#   color: #f1f1f1;
# }
# #T_de0b1_row0_col3, #T_de0b1_row8_col3, #T_de0b1_row10_col3, #T_de0b1_row16_col3, #T_de0b1_row19_col3, #T_de0b1_row22_col3, #T_de0b1_row24_col3, #T_de0b1_row28_col1, #T_de0b1_row28_col2, #T_de0b1_row28_col3, #T_de0b1_row35_col3, #T_de0b1_row37_col3, #T_de0b1_row38_col3, #T_de0b1_row44_col3, #T_de0b1_row50_col3, #T_de0b1_row54_col3, #T_de0b1_row75_col3, #T_de0b1_row78_col3, #T_de0b1_row85_col3, #T_de0b1_row88_col3, #T_de0b1_row109_col3 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_de0b1_row1_col1, #T_de0b1_row60_col1, #T_de0b1_row72_col2 {
#   background-color: #0d8044;
#   color: #f1f1f1;
# }
# #T_de0b1_row1_col2, #T_de0b1_row90_col1, #T_de0b1_row90_col2 {
#   background-color: #05713c;
#   color: #f1f1f1;
# }
# #T_de0b1_row1_col3, #T_de0b1_row5_col3, #T_de0b1_row9_col3, #T_de0b1_row21_col3, #T_de0b1_row61_col3, #T_de0b1_row70_col3, #T_de0b1_row71_col3, #T_de0b1_row72_col3, #T_de0b1_row79_col1, #T_de0b1_row93_col3, #T_de0b1_row99_col1, #T_de0b1_row100_col3 {
#   background-color: #57b65f;
#   color: #f1f1f1;
# }
# #T_de0b1_row2_col1, #T_de0b1_row30_col3, #T_de0b1_row68_col1, #T_de0b1_row93_col1 {
#   background-color: #93d168;
#   color: #000000;
# }
# #T_de0b1_row2_col2 {
#   background-color: #91d068;
#   color: #000000;
# }
# #T_de0b1_row2_col3, #T_de0b1_row14_col3, #T_de0b1_row15_col3, #T_de0b1_row17_col3, #T_de0b1_row25_col3, #T_de0b1_row29_col3, #T_de0b1_row32_col3, #T_de0b1_row36_col3, #T_de0b1_row43_col3, #T_de0b1_row46_col3, #T_de0b1_row47_col3, #T_de0b1_row51_col3, #T_de0b1_row58_col3, #T_de0b1_row63_col3, #T_de0b1_row64_col3, #T_de0b1_row68_col3, #T_de0b1_row69_col3, #T_de0b1_row77_col3, #T_de0b1_row81_col3, #T_de0b1_row82_col3, #T_de0b1_row87_col3, #T_de0b1_row88_col1, #T_de0b1_row88_col2, #T_de0b1_row94_col3, #T_de0b1_row97_col3, #T_de0b1_row98_col3, #T_de0b1_row103_col3 {
#   background-color: #ce2827;
#   color: #f1f1f1;
# }
# #T_de0b1_row3_col1 {
#   background-color: #9bd469;
#   color: #000000;
# }
# #T_de0b1_row3_col2 {
#   background-color: #96d268;
#   color: #000000;
# }
# #T_de0b1_row3_col3, #T_de0b1_row87_col1 {
#   background-color: #f88c51;
#   color: #f1f1f1;
# }
# #T_de0b1_row4_col1, #T_de0b1_row4_col2, #T_de0b1_row21_col1, #T_de0b1_row62_col1 {
#   background-color: #148e4b;
#   color: #f1f1f1;
# }
# #T_de0b1_row4_col3, #T_de0b1_row20_col3, #T_de0b1_row56_col3, #T_de0b1_row59_col3, #T_de0b1_row62_col3, #T_de0b1_row74_col3, #T_de0b1_row79_col3, #T_de0b1_row86_col2, #T_de0b1_row106_col3 {
#   background-color: #e5f49b;
#   color: #000000;
# }
# #T_de0b1_row5_col1 {
#   background-color: #3faa59;
#   color: #f1f1f1;
# }
# #T_de0b1_row5_col2, #T_de0b1_row11_col1, #T_de0b1_row23_col2, #T_de0b1_row30_col2, #T_de0b1_row80_col1, #T_de0b1_row83_col2 {
#   background-color: #30a356;
#   color: #f1f1f1;
# }
# #T_de0b1_row6_col1, #T_de0b1_row32_col2, #T_de0b1_row64_col1 {
#   background-color: #f4fab0;
#   color: #000000;
# }
# #T_de0b1_row6_col2 {
#   background-color: #e0f295;
#   color: #000000;
# }
# #T_de0b1_row6_col3, #T_de0b1_row34_col3, #T_de0b1_row41_col3, #T_de0b1_row86_col3 {
#   background-color: #fffab6;
#   color: #000000;
# }
# #T_de0b1_row7_col1 {
#   background-color: #f98e52;
#   color: #f1f1f1;
# }
# #T_de0b1_row7_col2, #T_de0b1_row18_col3, #T_de0b1_row31_col3, #T_de0b1_row91_col3 {
#   background-color: #fede89;
#   color: #000000;
# }
# #T_de0b1_row7_col3, #T_de0b1_row33_col3, #T_de0b1_row39_col3, #T_de0b1_row40_col3, #T_de0b1_row55_col3, #T_de0b1_row57_col3, #T_de0b1_row67_col3, #T_de0b1_row101_col3 {
#   background-color: #f36b42;
#   color: #f1f1f1;
# }
# #T_de0b1_row8_col1, #T_de0b1_row44_col1 {
#   background-color: #f7814c;
#   color: #f1f1f1;
# }
# #T_de0b1_row8_col2, #T_de0b1_row24_col1, #T_de0b1_row44_col2, #T_de0b1_row46_col1 {
#   background-color: #f67c4a;
#   color: #f1f1f1;
# }
# #T_de0b1_row9_col1 {
#   background-color: #0f8446;
#   color: #f1f1f1;
# }
# #T_de0b1_row9_col2 {
#   background-color: #0e8245;
#   color: #f1f1f1;
# }
# #T_de0b1_row10_col1, #T_de0b1_row58_col1 {
#   background-color: #fece7c;
#   color: #000000;
# }
# #T_de0b1_row10_col2 {
#   background-color: #feca79;
#   color: #000000;
# }
# #T_de0b1_row11_col2 {
#   background-color: #219c52;
#   color: #f1f1f1;
# }
# #T_de0b1_row11_col3, #T_de0b1_row23_col3, #T_de0b1_row42_col3, #T_de0b1_row94_col1, #T_de0b1_row98_col1, #T_de0b1_row98_col2 {
#   background-color: #f2faae;
#   color: #000000;
# }
# #T_de0b1_row12_col1, #T_de0b1_row31_col1 {
#   background-color: #04703b;
#   color: #f1f1f1;
# }
# #T_de0b1_row12_col2, #T_de0b1_row31_col2, #T_de0b1_row48_col2, #T_de0b1_row65_col1 {
#   background-color: #08773f;
#   color: #f1f1f1;
# }
# #T_de0b1_row12_col3, #T_de0b1_row29_col2, #T_de0b1_row80_col3, #T_de0b1_row99_col3 {
#   background-color: #fee593;
#   color: #000000;
# }
# #T_de0b1_row13_col1, #T_de0b1_row74_col2 {
#   background-color: #199750;
#   color: #f1f1f1;
# }
# #T_de0b1_row13_col2, #T_de0b1_row66_col2 {
#   background-color: #036e3a;
#   color: #f1f1f1;
# }
# #T_de0b1_row13_col3, #T_de0b1_row45_col3, #T_de0b1_row48_col3, #T_de0b1_row52_col3, #T_de0b1_row60_col3, #T_de0b1_row66_col3, #T_de0b1_row76_col3, #T_de0b1_row102_col1, #T_de0b1_row102_col2, #T_de0b1_row102_col3, #T_de0b1_row108_col3 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_de0b1_row14_col1 {
#   background-color: #f57245;
#   color: #f1f1f1;
# }
# #T_de0b1_row14_col2 {
#   background-color: #f7844e;
#   color: #f1f1f1;
# }
# #T_de0b1_row15_col1 {
#   background-color: #fff6b0;
#   color: #000000;
# }
# #T_de0b1_row15_col2, #T_de0b1_row85_col2 {
#   background-color: #fff7b2;
#   color: #000000;
# }
# #T_de0b1_row16_col1, #T_de0b1_row97_col2 {
#   background-color: #fdb96a;
#   color: #000000;
# }
# #T_de0b1_row16_col2, #T_de0b1_row22_col1 {
#   background-color: #fdb365;
#   color: #000000;
# }
# #T_de0b1_row17_col1, #T_de0b1_row35_col2, #T_de0b1_row46_col2, #T_de0b1_row84_col2, #T_de0b1_row109_col2 {
#   background-color: #fdad60;
#   color: #000000;
# }
# #T_de0b1_row17_col2 {
#   background-color: #fcaa5f;
#   color: #000000;
# }
# #T_de0b1_row18_col1 {
#   background-color: #84ca66;
#   color: #000000;
# }
# #T_de0b1_row18_col2 {
#   background-color: #82c966;
#   color: #000000;
# }
# #T_de0b1_row19_col1 {
#   background-color: #fff8b4;
#   color: #000000;
# }
# #T_de0b1_row19_col2 {
#   background-color: #fff3ac;
#   color: #000000;
# }
# #T_de0b1_row20_col1, #T_de0b1_row30_col1 {
#   background-color: #5ab760;
#   color: #f1f1f1;
# }
# #T_de0b1_row20_col2 {
#   background-color: #42ac5a;
#   color: #f1f1f1;
# }
# #T_de0b1_row21_col2 {
#   background-color: #0c7f43;
#   color: #f1f1f1;
# }
# #T_de0b1_row22_col2, #T_de0b1_row87_col2 {
#   background-color: #fdaf62;
#   color: #000000;
# }
# #T_de0b1_row23_col1, #T_de0b1_row76_col1, #T_de0b1_row99_col2 {
#   background-color: #39a758;
#   color: #f1f1f1;
# }
# #T_de0b1_row24_col2 {
#   background-color: #f57748;
#   color: #f1f1f1;
# }
# #T_de0b1_row25_col1, #T_de0b1_row38_col2 {
#   background-color: #fdc171;
#   color: #000000;
# }
# #T_de0b1_row25_col2, #T_de0b1_row58_col2 {
#   background-color: #fecc7b;
#   color: #000000;
# }
# #T_de0b1_row26_col2 {
#   background-color: #fb9d59;
#   color: #000000;
# }
# #T_de0b1_row26_col3, #T_de0b1_row39_col1, #T_de0b1_row81_col2, #T_de0b1_row84_col3, #T_de0b1_row96_col3 {
#   background-color: #ea5739;
#   color: #f1f1f1;
# }
# #T_de0b1_row27_col1 {
#   background-color: #f1f9ac;
#   color: #000000;
# }
# #T_de0b1_row27_col2, #T_de0b1_row73_col2 {
#   background-color: #eef8a8;
#   color: #000000;
# }
# #T_de0b1_row27_col3, #T_de0b1_row73_col3, #T_de0b1_row104_col3 {
#   background-color: #fba35c;
#   color: #000000;
# }
# #T_de0b1_row29_col1 {
#   background-color: #fee491;
#   color: #000000;
# }
# #T_de0b1_row32_col1 {
#   background-color: #eff8aa;
#   color: #000000;
# }
# #T_de0b1_row33_col1 {
#   background-color: #ca2427;
#   color: #f1f1f1;
# }
# #T_de0b1_row33_col2 {
#   background-color: #de402e;
#   color: #f1f1f1;
# }
# #T_de0b1_row34_col1 {
#   background-color: #70c164;
#   color: #000000;
# }
# #T_de0b1_row34_col2, #T_de0b1_row42_col1, #T_de0b1_row61_col2, #T_de0b1_row71_col1 {
#   background-color: #6bbf64;
#   color: #000000;
# }
# #T_de0b1_row35_col1, #T_de0b1_row109_col1 {
#   background-color: #fdb163;
#   color: #000000;
# }
# #T_de0b1_row36_c

# %% [markdown]
# ## 12. Plots
#
# Three visualizations:
#
# - **12a.** Bar chart: all three metrics per attack, side by side. Quickly identifies which attacks have high uncertainty.
# - **12b.** Scatter: PE\_norm vs SE\_norm. Both are per-token entropy on the same scale, so the y=x diagonal is meaningful. Points below the line = clustering reduced uncertainty (phrasing variation removed). Points on the line = no clustering benefit (genuine semantic disagreement).
# - **12c.** Histograms: distribution of each metric across all attacks. Shows whether most attacks are low-uncertainty (model is generally reliable) or spread out (mixed reliability).

# %%
# ── 12a. Three metrics per attack ────────────────────────
fig, ax = plt.subplots(figsize=(max(14, len(df) * 0.7), 5))
x = np.arange(len(df))
w = 0.25
ax.bar(x - w, df.pe_norm, w, label="PE (normalized)", color="#d9534f")
ax.bar(x,     df.se_norm, w, label="SE (normalized)", color="#5cb85c")
ax.bar(x + w, df.dse,     w, label="Discrete SE", color="#5bc0de")
ax.set_xticks(x)
ax.set_xticklabels([a[:15] for a in df.attack], fontsize=7, rotation=45, ha="right")
ax.set_ylabel("Entropy")
ax.set_title(f"Uncertainty per Attack (M={M})")
ax.legend(fontsize=8)
plt.tight_layout()
plt.show()

# %%
# ── 12b. PE_norm vs SE_norm scatter ────────────────────────
fig, ax = plt.subplots(figsize=(7, 6))
ax.scatter(df.pe_norm, df.se_norm, s=60, c="#5cb85c", edgecolors="black", linewidths=0.5)
for _, row in df.iterrows():
    ax.annotate(row.attack[:12], (row.pe_norm + 0.002, row.se_norm + 0.002), fontsize=6)
lim = max(df.pe_norm.max(), df.se_norm.max()) + 0.05
ax.plot([0, lim], [0, lim], "k--", alpha=0.3, label="SE = PE (no clustering benefit)")
ax.fill_between([0, lim], [0, lim], [0, 0], alpha=0.05, color="green",
                label="SE < PE (clustering helps)")
ax.set_xlabel("Predictive Entropy (normalized)")
ax.set_ylabel("Semantic Entropy (normalized)")
ax.set_title("PE vs SE — both length-normalized, same scale")
ax.legend(fontsize=8)
ax.set_xlim(0, lim); ax.set_ylim(0, lim)
plt.tight_layout()
plt.show()
print("SE <= PE guaranteed. Gap = phrasing uncertainty removed by clustering.")
# Out:
# SE <= PE guaranteed. Gap = phrasing uncertainty removed by clustering.

# %%
# ── 12c. Distributions ────────────────────────────────────
fig, axes = plt.subplots(1, 3, figsize=(14, 3.5), sharey=True)
for ax, col, label, color in zip(axes,
    ["pe_norm", "se_norm", "dse"],
    ["PE (normalized)", "SE (normalized)", "Discrete SE"],
    ["#d9534f", "#5cb85c", "#5bc0de"]):
    ax.hist(df[col], bins=15, color=color, edgecolor="white", alpha=0.85)
    ax.set_title(label, fontsize=9)
    ax.set_xlabel("Entropy")
    ax.axvline(df[col].mean(), color="black", linestyle="--", linewidth=0.8,
               label=f"μ={df[col].mean():.4f}")
    ax.legend(fontsize=7)
axes[0].set_ylabel("Count")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 13. Highest-uncertainty attacks
#
# Top 10 attacks ranked by normalized semantic entropy ($SE_{\text{norm}}$). These are the attacks where the model is **least confident about the meaning** of its mitigations — different runs produce semantically different lists.
#
# These outputs should be treated with caution: the mitigations may be hallucinated, incomplete, or inconsistently prioritized. Consider manual review or using a more capable model for these specific attacks.

# %%
top_n = min(10, len(df))
df.nlargest(top_n, "se_norm")[
    ["attack", "pe_norm", "se_norm", "dse", "clusters_nli", "avg_tokens"]
].style.format({
    "pe_norm": "{:.6f}", "se_norm": "{:.6f}", "dse": "{:.6f}", "avg_tokens": "{:.0f}"
}).background_gradient(subset=["pe_norm", "se_norm", "dse"], cmap="Reds")
# Out:
# <style type="text/css">
# #T_284f5_row0_col1, #T_284f5_row0_col2, #T_284f5_row0_col3, #T_284f5_row1_col3, #T_284f5_row2_col3, #T_284f5_row5_col3, #T_284f5_row8_col3, #T_284f5_row9_col3 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_284f5_row1_col1, #T_284f5_row1_col2 {
#   background-color: #f03d2d;
#   color: #f1f1f1;
# }
# #T_284f5_row2_col1, #T_284f5_row2_col2 {
#   background-color: #f75c41;
#   color: #f1f1f1;
# }
# #T_284f5_row3_col1 {
#   background-color: #cb181d;
#   color: #f1f1f1;
# }
# #T_284f5_row3_col2 {
#   background-color: #fb7555;
#   color: #f1f1f1;
# }
# #T_284f5_row3_col3, #T_284f5_row6_col3 {
#   background-color: #f34c37;
#   color: #f1f1f1;
# }
# #T_284f5_row4_col1 {
#   background-color: #e32f27;
#   color: #f1f1f1;
# }
# #T_284f5_row4_col2 {
#   background-color: #fc8565;
#   color: #f1f1f1;
# }
# #T_284f5_row4_col3, #T_284f5_row7_col3, #T_284f5_row9_col1, #T_284f5_row9_col2 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# #T_284f5_row5_col1, #T_284f5_row5_col2 {
#   background-color: #fcb398;
#   color: #000000;
# }
# #T_284f5_row6_col1 {
#   background-color: #fcb296;
#   color: #000000;
# }
# #T_284f5_row6_col2 {
#   background-color: #fcbca2;
#   color: #000000;
# }
# #T_284f5_row7_col1 {
#   background-color: #fcb69b;
#   color: #000000;
# }
# #T_284f5_row7_col2 {
#   background-color: #fdd4c2;
#   color: #000000;
# }
# #T_284f5_row8_col1, #T_284f5_row8_col2 {
#   background-color: #fdd7c6;
#   color: #000000;
# }
# </style>
# <table id="T_284f5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_284f5_level0_col0" class="col_heading level0 col0" >attack</th>
#       <th id="T_284f5_level0_col1" class="col_heading level0 col1" >pe_norm</th>
#       <th id="T_284f5_level0_col2" class="col_heading level0 col2" >se_norm</th>
#       <th id="T_284f5_level0_col3" class="col_heading level0 col3" >dse</th>
#       <th id="T_284f5_level0_col4" class="col_heading level0 col4" >clusters_nli</th>
#       <th id="T_284f5_level0_col5" class="col_heading level0 col5" >avg_tokens</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_284f5_level0_row0" class="row_heading level0 row0" >28</th>
#       <td id="T_284f5_row0_col0" class="data row0 col0" >Collect Data from Registries</td>
#       <td id="T_284f5_row0_col1" class="data row0 col1" >0.404868</td>
#       <td id="T_284f5_row0_col2" class="data row0 col2" >0.404868</td>
#       <td id="T_284f5_row0_col3" class="data row0 col3" >2.079442</td>
#       <td id="T_284f5_row0_col4" class="data row0 col4" >8</td>
#       <td id="T_284f5_row0_col5" class="data row0 col5" >170</td>
#     </tr>
#     <tr>
#       <th id="T_284f5_level0_row1" class="row_heading level0 row1" >88</th>
#       <td id="T_284f5_row1_col0" class="data row1 col0" >Signature Spoofing by Key Recreation</td>
#       <td id="T_284f5_row1_col1" class="data row1 col1" >0.371985</td>
#       <td id="T_284f5_row1_col2" class="data row1 col2" >0.371985</td>
#       <td id="T_284f5_row1_col3" class="data row1 col3" >2.079442</td>
#       <td id="T_284f5_row1_col4" class="data row1 col4" >8</td>
#       <td id="T_284f5_row1_col5" class="data row1 col5" >149</td>
#     </tr>
#     <tr>
#       <th id="T_284f5_level0_row2" class="row_heading level0 row2" >54</th>
#       <td id="T_284f5_row2_col0" class="data row2 col0" >Serialized Data External Linking</td>
#       <td id="T_284f5_row2_col1" class="data row2 col1" >0.364916</td>
#       <td id="T_284f5_row2_col2" class="data row2 col2" >0.364916</td>
#       <td id="T_284f5_row2_col3" class="data row2 col3" >2.079442</td>
#       <td id="T_284f5_row2_col4" class="data row2 col4" >8</td>
#       <td id="T_284f5_row2_col5" class="data row2 col5" >124</td>
#     </tr>
#     <tr>
#       <th id="T_284f5_level0_row3" class="row_heading level0 row3" >82</th>
#       <td id="T_284f5_row3_col0" class="data row3 col0" >Creating a Rogue Certification Authority Certificate</td>
#       <td id="T_284f5_row3_col1" class="data row3 col1" >0.383027</td>
#       <td id="T_284f5_row3_col2" class="data row3 col2" >0.358599</td>
#       <td id="T_284f5_row3_col3" class="data row3 col3" >1.906155</td>
#       <td id="T_284f5_row3_col4" class="data row3 col4" >7</td>
#       <td id="T_284f5_row3_col5" class="data row3 col5" >140</td>
#     </tr>
#     <tr>
#       <th id="T_284f5_level0_row4" class="row_heading level0 row4" >33</th>
#       <td id="T_284f5_row4_col0" class="data row4 col0" >Cross-Domain Search Timing</td>
#       <td id="T_284f5_row4_col1" class="data row4 col1" >0.375809</td>
#       <td id="T_284f5_row4_col2" class="data row4 col2" >0.354354</td>
#       <td id="T_284f5_row4_col3" class="data row4 col3" >1.667462</td>
#       <td id="T_284f5_row4_col4" class="data row4 col4" >6</td>
#       <td id="T_284f5_row4_col5" class="data row4 col5" >85</td>
#     </tr>
#     <tr>
#       <th id="T_284f5_level0_row5" class="row_heading level0 row5" >78</th>
#       <td id="T_284f5_row5_col0" class="data row5 col0" >Spoofing of UDDI/ebXML Messages</td>
#       <td id="T_284f5_row5_col1" class="data row5 col1" >0.342095</td>
#       <td id="T_284f5_row5_col2" class="data row5 col2" >0.342095</td>
#       <td id="T_284f5_row5_col3" class="data row5 col3" >2.079442</td>
#       <td id="T_284f5_row5_col4" class="data row5 col4" >8</td>
#       <td id="T_284f5_row5_col5" class="data row5 col5" >115</td>
#     </tr>
#     <tr>
#       <th id="T_284f5_level0_row6" class="row_heading level0 row6" >81</th>
#       <td id="T_284f5_row6_col0" class="data row6 col0" >Token Impersonation</td>
#       <td id="T_284f5_row6_col1" class="data row6 col1" >0.342639</td>
#       <td id="T_284f5_row6_col2" class="data row6 col2" >0.339699</td>
#       <td id="T_284f5_row6_col3" class="data row6 col3" >1.906155</td>
#       <td id="T_284f5_row6_col4" class="data row6 col4" >7</td>
#       <td id="T_284f5_row6_col5" class="data row6 col5" >190</td>
#     </tr>
#     <tr>
#       <th id="T_284f5_level0_row7" class="row_heading level0 row7" >39</th>
#       <td id="T_284f5_row7_col0" class="data row7 col0" >Capture Credentials via Keylogger</td>
#       <td id="T_284f5_row7_col1" class="data row7 col1" >0.341603</td>
#       <td id="T_284f5_row7_col2" class="data row7 col2" >0.332698</td>
#       <td id="T_284f5_row7_col3" class="data row7 col3" >1.667462</td>
#       <td id="T_284f5_row7_col4" class="data row7 col4" >6</td>
#       <td id="T_284f5_row7_col5" class="data row7 col5" >151</td>
#     </tr>
#     <tr>
#       <th id="T_284f5_level0_row8" class="row_heading level0 row8" >0</th>
#       <td id="T_284f5_row8_col0" class="data row8 col0" >Session Credential Falsification through Manipulation</td>
#       <td id="T_284f5_row8_col1" class="data row8 col1" >0.332041</td>
#       <td id="T_284f5_row8_col2" class="data row8 col2" >0.332041</td>
#       <td id="T_284f5_row8_col3" class="data row8 col3" >2.079442</td>
#       <td id="T_284f5_row8_col4" class="data row8 col4" >8</td>
#       <td id="T_284f5_row8_col5" class="data row8 col5" >216</td>
#     </tr>
#     <tr>
#       <th id="T_284f5_level0_row9" class="row_heading level0 row9" >24</th>
#       <td id="T_284f5_row9_col0" class="data row9 col0" >Detect Unpublicized Web Pages</td>
#       <td id="T_284f5_row9_col1" class="data row9 col1" >0.318351</td>
#       <td id="T_284f5_row9_col2" class="data row9 col2" >0.318351</td>
#       <td id="T_284f5_row9_col3" class="data row9 col3" >2.079442</td>
#       <td id="T_284f5_row9_col4" class="data row9 col4" >8</td>
#       <td id="T_284f5_row9_col5" class="data row9 col5" >204</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## 14. Save results
#
# Exports a CSV with one row per attack. **Primary columns** (comparable across attacks):
#
# - `pe_norm` — predictive entropy per token: how surprised is the model?
# - `se_norm` — semantic entropy per token: how much semantic disagreement?
# - `dse` — discrete semantic entropy: how many distinct meanings? (no log-probs needed)
#
# **Reference columns** (raw, not comparable across attacks): `pe`, `se`.
#
# **Interpretation guide:**
# - High `se_norm` + high `dse` → the model gives genuinely different answers → **unreliable**
# - Low `se_norm` + low `dse` → the model is semantically consistent → **reliable**
# - High `pe_norm` but low `se_norm` → different phrasing, same meaning → **reliable** (just verbose)

# %%
# ── Build filename with model name ──
model_tag = OLLAMA_MODEL.replace(":", "_").replace("/", "_") if BACKEND == "ollama" else LLM_NAME.split("/")[-1]
fname = f"entropy_results_{model_tag}.csv"

# ── Save ──
save_cols = ["attack",
             "pe_norm", "se_norm", "dse",      # comparable across attacks
             "pe", "se",                        # raw (for reference)
             "clusters_nli", "avg_tokens"]
clean_df = df[save_cols].copy()
clean_df.to_csv(fname, index=False)
print(f"Saved {len(clean_df)} rows → {fname}")
print(f"Model: {OLLAMA_MODEL if BACKEND == 'ollama' else LLM_NAME}\n")
print("Columns:")
print("  pe_norm — predictive entropy / avg tokens (per-token surprise)")
print("  se_norm — semantic entropy / avg tokens (per-token, cluster-weighted)")
print("  dse     — discrete semantic entropy (cluster counts, length-free)")
print("  pe, se  — raw values (not comparable across attacks)")
print()
clean_df
# Out:
# Saved 110 rows → entropy_results_llama3.1_8b.csv
# Model: llama3.1:8b
#
# Columns:
#   pe_norm — predictive entropy / avg tokens (per-token surprise)
#   se_norm — semantic entropy / avg tokens (per-token, cluster-weighted)
#   dse     — discrete semantic entropy (cluster counts, length-free)
#   pe, se  — raw values (not comparable across attacks)
#                                                 attack   pe_norm   se_norm  \
# 0    Session Credential Falsification through Manip...  0.332041  0.332041
# 1    Session Credential Falsification through Predi...  0.040584  0.017474
# 2                                  Session Sidejacking  0.125248  0.114589
# 3                                   Cross Site Tracing  0.128732  0.116776
# 4             Reusing Session IDs (aka Session Replay)  0.050707  0.039623
# ..                                                 ...       ...       ...
# 105                                     Symlink Attack  0.109737  0.084236
# 106  Leveraging/Manipulating Configuration File Sea...  0.095069  0.055769
# 107                             Search Order Hijacking  0.096303  0.084209
# 108                                   DLL Side-Loading  0.029693  0.010332
# 109                             Evil Twin Wi-Fi Attack  0.286612  0.286612
#
#           dse         pe         se  clusters_nli  avg_tokens
# 0    2.079442  71.596291  71.596291             8       215.6
# 1    0.376770   7.061609   3.040539             2       174.0
# 2    1.906155  11.867228  10.857344             7        94.8
# 3    1.559581   8.351518   7.575848             5        64.9
# 4    0.900256   9.621742   7.518435             3       189.8
# ..        ...        ...        ...           ...         ...
# 105  1.386294  11.001117   8.444656             5       100.2
# 106  0.900256   9.804014   5.751211             3       103.1
# 107  1.386294   7.282895   6.368330             5        75.6
# 108  0.000000   4.646893   1.616934             1       156.5
# 109  2.079442  44.389016  44.389016             8       154.9
#
# [110 rows x 8 columns]
